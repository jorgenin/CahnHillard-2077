# %% [markdown]
# # Code for Cahn-Hilliard phase separation with mechanical coupling.

# %% [markdown]
# ## 2D phase separation study.

# %% [markdown]
# Degrees of freedom:
#   - scalar chemical potential: we use normalized  mu = mu/RT
#   - species concentration:  we use normalized  c= Omega*cmat
#
# ### Units:
# - Length: um
# - Mass: kg
# - Time: s
# - Amount of substance: pmol
# - Temperature: K
# - Mass density: kg/um^3
# - Force: uN
# - Stress: MPa
# - Energy: pJ
# - Species concentration: pmol/um^3
# - Chemical potential: pJ/pmol
# - Molar volume: um^3/pmol
# - Species diffusivity: um^2/s
# - Boltzmann Constant: 1.38E-11 pJ/K
# - Gas constant: 8.314  pJ/(pmol K)
#
# ### By
#   Eric Stewart      and      Lallit Anand
# ericstew@mit.edu            anand@mit.edu
#
# October 2023
#
# Modified for FenicsX by Jorge Nin
# jorgenin@mit.edu

# %%
import numpy as np


from mpi4py import MPI
from petsc4py import PETSc

from dolfinx import fem, mesh, io, plot, log, default_scalar_type
from dolfinx.fem import Constant, dirichletbc, Function, FunctionSpace, Expression
from dolfinx.fem.petsc import NonlinearProblem
from dolfinx.nls.petsc import NewtonSolver
from dolfinx.io import VTXWriter

import ufl
from ufl import (
    TestFunction,
    TrialFunction,
    Identity,
    grad,
    det,
    div,
    dev,
    inv,
    tr,
    sqrt,
    conditional,
    gt,
    dx,
    inner,
    derivative,
    dot,
    ln,
    split,
    tanh,
    as_tensor,
    as_vector,
    ge
)

from hilliard_models import Cahn_Hillard_axi_symmetric
from datetime import datetime
from dolfinx.plot import vtk_mesh

import pyvista

pyvista.set_jupyter_backend("client")
## Define temporal parameters
import random

# %% [markdown]
# # DEFINE GEOMETRY

# %%
problemName = "Canh Hillard Mechanical Axi Symetric"

# Square edge length
L0 = 0.8  # 800 nm box, after Di Leo et al. (2014)

# Number of elements along each side
N = 20

# Create square mesh
domain = mesh.create_rectangle(MPI.COMM_WORLD, [(0, 0), (L0, L0)], [N, N])

# %% [markdown]
# ## Visualize the geometry

# %%
plotter = pyvista.Plotter()
vtkdata = vtk_mesh(domain, domain.topology.dim)
grid = pyvista.UnstructuredGrid(*vtkdata)
actor = plotter.add_mesh(grid, show_edges=True)
plotter.show()
plotter.close()
# Out:
# Widget(value="<iframe src='http://localhost:58915/index.html?ui=P_0x29d3aba90_0&reconnect=auto' style='width: …

# %% [markdown]
# # Periodicity

# %%
def inside(self, x, on_boundary):
    # return True if on left or bottom boundary AND NOT
    # on one of the two corners (0, L0) and (L0, 0)
    return bool(
        (np.isclose(x[0], 0) or np.isclose(x[1], 0))
        and (
            not (
                (np.isclose(x[0], 0) and np.isclose(x[1], L0))
                or (np.isclose(x[0], L0) and np.isclose(x[1], 0))
            )
        )
        and on_boundary
    )


def map(self, x, y):
    if np.isclose(x[0], L0) and np.isclose(x[1], L0):
        y[0] = x[0] - L0
        y[1] = x[1] - L0
    elif np.isclose(x[0], L0):
        y[0] = x[0] - L0
        y[1] = x[1]
    else:  # np.isclose(x[1], L0)
        y[0] = x[0]
        y[1] = x[1] - L0

# %% [markdown]
# # Simulation Time Control

# %%
t = 0.0  # initialization of time
Ttot = 4  # total simulation time
dt = 0.01  # Initial time step size, here we will use adaptive time-stepping

# %% [markdown]
# # Create Problem

# %%
dk = Constant(domain,dt)

hillard_problem = Cahn_Hillard_axi_symmetric(domain)
hillard_problem.Kinematics()
hillard_problem.WeakForms(dk)

# %% [markdown]
# # Setup Output Files

# %%
U1 = ufl.VectorElement("Lagrange", domain.ufl_cell(), 1)
V2 = fem.FunctionSpace(domain, U1)#Vector function space
V1 = fem.FunctionSpace(domain, hillard_problem.P1)#Scalar function space

u_vis = Function(V2)
u_vis.name = "u"
u_expr = Expression(hillard_problem.u,V2.element.interpolation_points())


mu_vis = Function(V1)
mu_vis.name = "mu"
mu_expr = Expression(hillard_problem.mu,V1.element.interpolation_points())

c_vis = Function(V1)
c_vis.name = "c"
c_expr = Expression(hillard_problem.c,V1.element.interpolation_points())


T = hillard_problem.T
T2D = as_tensor([[T[0,0], T[0,1]],
                                    [T[1,0], T[1,1]]])

sigma1, sigma2, vec1, vec2 = hillard_problem.eigs(T2D)

sigma1_vis = Function(V1)
sigma1_vis.name = "sigma1"
sigma1_expr = Expression(sigma1*hillard_problem.Gshear,V1.element.interpolation_points())

sigma2_vis = Function(V1)
sigma2_vis.name = "sigma2"
sigma2_expr = Expression(sigma2*hillard_problem.Gshear,V1.element.interpolation_points())


#vtk2 = VTXWriter(domain.comm,"results/"+problemName+"displacement.bp", [u_vis], engine="BP4" )

vtk = VTXWriter(domain.comm,"results/"+problemName+"scalrValues.bp", [u_vis,mu_vis,c_vis,sigma1_vis,sigma2_vis], engine="BP4" )

files = [vtk]

def interp_and_save(t, files: list[VTXWriter]):
    u_vis.interpolate(u_expr)
    mu_vis.interpolate(mu_expr)
    c_vis.interpolate(c_expr)
    sigma2_vis.interpolate(sigma2_expr)
    sigma1_vis.interpolate(sigma1_expr)

    for file in files:
        file.write(t)

# %% [markdown]
# # Boundary Conditions

# %%
#Locate the boundary
def bottom(x):
    return np.isclose(x[1], 0)


def right(x):
    return np.isclose(x[0], 0)


fdim = domain.topology.dim - 1
left_facets = mesh.locate_entities_boundary(domain, fdim, right)
bottom_facets = mesh.locate_entities_boundary(domain, fdim, bottom)

marked_facets = np.hstack([bottom_facets, left_facets])
marked_values = np.hstack([np.full_like(bottom_facets, 1), np.full_like(left_facets, 2)])
sorted_facets = np.argsort(marked_facets)

facet_tag = mesh.meshtags(domain, fdim, marked_facets[sorted_facets], marked_values[sorted_facets])

# %%
# Just fix the sides to make sure they don't move

u_bc = np.array((0), dtype=default_scalar_type)




left_dofs = fem.locate_dofs_topological(hillard_problem.ME.sub(0).sub(0), facet_tag.dim, facet_tag.find(2)) #we don't want it to move in the x direction
bottom_dofs = fem.locate_dofs_topological(hillard_problem.ME.sub(0).sub(1), facet_tag.dim, facet_tag.find(1)) #we don't want it to move in the y direction
bcs = [fem.dirichletbc(u_bc, left_dofs, hillard_problem.ME.sub(0).sub(0)),
       fem.dirichletbc(u_bc, bottom_dofs, hillard_problem.ME.sub(0).sub(1))]

# %% [markdown]
# # Setup Nonlinear Problem

# %%
import os
step = "Swell"
jit_options ={"cffi_extra_compile_args":["-O3","-ffast-math"]}

problem = NonlinearProblem(hillard_problem.Res,hillard_problem.w, bcs, hillard_problem.a)


solver = NewtonSolver(MPI.COMM_WORLD, problem)
solver.convergence_criterion = "incremental"
solver.rtol = 1e-8
solver.atol = 1e-8
solver.max_it = 50
solver.report = True
solver.error_on_nonconvergence = False

ksp = solver.krylov_solver
opts = PETSc.Options()
option_prefix = ksp.getOptionsPrefix()
opts[f"{option_prefix}ksp_max_it"] = 30
#opts[f"{option_prefix}ksp_type"] = "cg"
#opts[f"{option_prefix}pc_type"] = "ksp"
ksp.setFromOptions()

startTime = datetime.now()
print("------------------------------------")
print("Simulation Start")
print("------------------------------------")

step = "Evolve"

#if os.path.exists("results/"+problemName+".bp"):
#    os.remove("results/"+problemName+".xdmf")
#    os.remove("results/"+problemName+".h5")

#vtk.write_mesh(domain)
t = 0.0

interp_and_save(t, files)
ii = 0
bisection_count = 0
while t < Ttot:
    # increment time
    t += float(dk) 
    # increment counter
    ii +=1
    

    # Solve the problem
    
    (iter, converged) = solver.solve(hillard_problem.w)
    
    if converged:
        hillard_problem.w.x.scatter_forward()
        
        
        
        hillard_problem.w_old.x.array[:] = hillard_problem.w.x.array
        
        interp_and_save(t, files)
        if ii % 1 == 0:
            now = datetime.now()
            current_time = now.strftime("%H:%M:%S")
            print("Step: {} |   Increment: {} | Iterations: {}".format(step, ii, iter))
            print("Simulation Time: {} s | dt: {} s".format(round(t, 2), round(dt, 3)))
            print()
        
        if iter <= 2:
            dt = 1.5 * dt
            dk.value = dt
        # If the newton solver takes 5 or more iterations,
        # decrease the time step by a factor of 2:
        elif iter >= 5:
            dt = dt / 2
            dk.value =dt

        #Reset Biseciton Counter
        bisection_count = 0
        
    else:
     # Break the loop if solver fails too many times
        bisection_count += 1
        
        if bisection_count > 5:
            print("Error: Too many bisections")
            break
        
        print( "Error Halfing Time Step")
        t = t - float(dk)
        dt = dt / 2
        dk.value = dt
        print(f"New Time Step: {dt}")
        hillard_problem.w.x.array[:] = hillard_problem.w_old.x.array
        

#End Analysis

for file in files:
    file.close()
endTime = datetime.now()
print("------------------------------------")
print("Simulation End")
print("------------------------------------")
print("Total Time: {}".format(endTime - startTime))
print("------------------------------------")
# Out:
# ------------------------------------
# Simulation Start
# ------------------------------------
# Step: Evolve |   Increment: 1 | Iterations: 5
# Simulation Time: 0.01 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 2 | Iterations: 3
# Simulation Time: 0.01 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 3 | Iterations: 3
# Simulation Time: 0.02 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 4 | Iterations: 3
# Simulation Time: 0.03 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 5 | Iterations: 3
# Simulation Time: 0.03 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 6 | Iterations: 3
# Simulation Time: 0.04 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 7 | Iterations: 3
# Simulation Time: 0.04 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 8 | Iterations: 3
# Simulation Time: 0.04 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 9 | Iterations: 3
# Simulation Time: 0.05 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 10 | Iterations: 3
# Simulation Time: 0.05 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 11 | Iterations: 3
# Simulation Time: 0.06 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 12 | Iterations: 3
# Simulation Time: 0.06 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 13 | Iterations: 3
# Simulation Time: 0.07 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 14 | Iterations: 3
# Simulation Time: 0.07 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 15 | Iterations: 3
# Simulation Time: 0.08 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 16 | Iterations: 3
# Simulation Time: 0.09 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 17 | Iterations: 3
# Simulation Time: 0.09 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 18 | Iterations: 3
# Simulation Time: 0.1 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 19 | Iterations: 3
# Simulation Time: 0.1 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 20 | Iterations: 3
# Simulation Time: 0.11 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 21 | Iterations: 3
# Simulation Time: 0.11 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 22 | Iterations: 3
# Simulation Time: 0.12 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 23 | Iterations: 3
# Simulation Time: 0.12 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 24 | Iterations: 3
# Simulation Time: 0.13 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 25 | Iterations: 3
# Simulation Time: 0.13 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 26 | Iterations: 3
# Simulation Time: 0.14 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 27 | Iterations: 3
# Simulation Time: 0.14 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 28 | Iterations: 3
# Simulation Time: 0.15 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 29 | Iterations: 3
# Simulation Time: 0.15 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 30 | Iterations: 3
# Simulation Time: 0.16 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 31 | Iterations: 3
# Simulation Time: 0.16 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 32 | Iterations: 3
# Simulation Time: 0.17 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 33 | Iterations: 3
# Simulation Time: 0.17 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 34 | Iterations: 3
# Simulation Time: 0.18 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 35 | Iterations: 3
# Simulation Time: 0.18 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 36 | Iterations: 3
# Simulation Time: 0.19 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 37 | Iterations: 3
# Simulation Time: 0.19 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 38 | Iterations: 3
# Simulation Time: 0.2 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 39 | Iterations: 3
# Simulation Time: 0.2 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 40 | Iterations: 3
# Simulation Time: 0.21 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 41 | Iterations: 3
# Simulation Time: 0.21 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 42 | Iterations: 3
# Simulation Time: 0.22 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 43 | Iterations: 3
# Simulation Time: 0.22 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 44 | Iterations: 3
# Simulation Time: 0.23 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 45 | Iterations: 3
# Simulation Time: 0.23 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 46 | Iterations: 3
# Simulation Time: 0.24 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 47 | Iterations: 3
# Simulation Time: 0.24 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 48 | Iterations: 3
# Simulation Time: 0.25 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 49 | Iterations: 3
# Simulation Time: 0.25 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 50 | Iterations: 3
# Simulation Time: 0.26 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 51 | Iterations: 3
# Simulation Time: 0.26 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 52 | Iterations: 3
# Simulation Time: 0.27 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 53 | Iterations: 3
# Simulation Time: 0.27 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 54 | Iterations: 3
# Simulation Time: 0.28 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 55 | Iterations: 3
# Simulation Time: 0.28 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 56 | Iterations: 3
# Simulation Time: 0.29 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 57 | Iterations: 3
# Simulation Time: 0.29 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 58 | Iterations: 3
# Simulation Time: 0.3 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 59 | Iterations: 3
# Simulation Time: 0.3 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 60 | Iterations: 3
# Simulation Time: 0.31 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 61 | Iterations: 3
# Simulation Time: 0.31 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 62 | Iterations: 3
# Simulation Time: 0.32 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 63 | Iterations: 3
# Simulation Time: 0.32 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 64 | Iterations: 3
# Simulation Time: 0.33 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 65 | Iterations: 3
# Simulation Time: 0.33 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 66 | Iterations: 3
# Simulation Time: 0.34 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 67 | Iterations: 3
# Simulation Time: 0.34 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 68 | Iterations: 3
# Simulation Time: 0.35 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 69 | Iterations: 3
# Simulation Time: 0.35 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 70 | Iterations: 3
# Simulation Time: 0.36 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 71 | Iterations: 3
# Simulation Time: 0.36 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 72 | Iterations: 3
# Simulation Time: 0.37 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 73 | Iterations: 3
# Simulation Time: 0.37 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 74 | Iterations: 3
# Simulation Time: 0.38 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 75 | Iterations: 3
# Simulation Time: 0.38 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 76 | Iterations: 3
# Simulation Time: 0.39 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 77 | Iterations: 3
# Simulation Time: 0.39 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 78 | Iterations: 3
# Simulation Time: 0.4 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 79 | Iterations: 3
# Simulation Time: 0.4 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 80 | Iterations: 3
# Simulation Time: 0.41 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 81 | Iterations: 3
# Simulation Time: 0.41 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 82 | Iterations: 3
# Simulation Time: 0.42 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 83 | Iterations: 3
# Simulation Time: 0.42 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 84 | Iterations: 3
# Simulation Time: 0.43 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 85 | Iterations: 3
# Simulation Time: 0.43 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 86 | Iterations: 3
# Simulation Time: 0.44 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 87 | Iterations: 3
# Simulation Time: 0.44 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 88 | Iterations: 3
# Simulation Time: 0.45 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 89 | Iterations: 3
# Simulation Time: 0.45 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 90 | Iterations: 3
# Simulation Time: 0.46 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 91 | Iterations: 3
# Simulation Time: 0.46 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 92 | Iterations: 3
# Simulation Time: 0.47 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 93 | Iterations: 3
# Simulation Time: 0.47 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 94 | Iterations: 3
# Simulation Time: 0.48 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 95 | Iterations: 3
# Simulation Time: 0.48 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 96 | Iterations: 3
# Simulation Time: 0.49 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 97 | Iterations: 3
# Simulation Time: 0.49 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 98 | Iterations: 3
# Simulation Time: 0.5 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 99 | Iterations: 3
# Simulation Time: 0.5 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 100 | Iterations: 3
# Simulation Time: 0.51 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 101 | Iterations: 3
# Simulation Time: 0.51 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 102 | Iterations: 3
# Simulation Time: 0.52 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 103 | Iterations: 3
# Simulation Time: 0.52 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 104 | Iterations: 3
# Simulation Time: 0.53 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 105 | Iterations: 3
# Simulation Time: 0.53 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 106 | Iterations: 3
# Simulation Time: 0.54 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 107 | Iterations: 3
# Simulation Time: 0.54 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 108 | Iterations: 3
# Simulation Time: 0.55 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 109 | Iterations: 3
# Simulation Time: 0.55 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 110 | Iterations: 3
# Simulation Time: 0.56 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 111 | Iterations: 3
# Simulation Time: 0.56 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 112 | Iterations: 3
# Simulation Time: 0.57 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 113 | Iterations: 3
# Simulation Time: 0.57 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 114 | Iterations: 3
# Simulation Time: 0.58 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 115 | Iterations: 3
# Simulation Time: 0.58 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 116 | Iterations: 3
# Simulation Time: 0.59 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 117 | Iterations: 3
# Simulation Time: 0.59 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 118 | Iterations: 3
# Simulation Time: 0.6 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 119 | Iterations: 3
# Simulation Time: 0.6 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 120 | Iterations: 3
# Simulation Time: 0.61 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 121 | Iterations: 3
# Simulation Time: 0.61 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 122 | Iterations: 3
# Simulation Time: 0.62 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 123 | Iterations: 3
# Simulation Time: 0.62 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 124 | Iterations: 3
# Simulation Time: 0.63 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 125 | Iterations: 3
# Simulation Time: 0.63 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 126 | Iterations: 3
# Simulation Time: 0.64 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 127 | Iterations: 3
# Simulation Time: 0.64 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 128 | Iterations: 3
# Simulation Time: 0.65 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 129 | Iterations: 3
# Simulation Time: 0.65 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 130 | Iterations: 3
# Simulation Time: 0.66 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 131 | Iterations: 3
# Simulation Time: 0.66 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 132 | Iterations: 3
# Simulation Time: 0.67 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 133 | Iterations: 3
# Simulation Time: 0.67 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 134 | Iterations: 3
# Simulation Time: 0.68 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 135 | Iterations: 3
# Simulation Time: 0.68 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 136 | Iterations: 3
# Simulation Time: 0.69 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 137 | Iterations: 3
# Simulation Time: 0.69 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 138 | Iterations: 3
# Simulation Time: 0.7 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 139 | Iterations: 3
# Simulation Time: 0.7 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 140 | Iterations: 3
# Simulation Time: 0.71 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 141 | Iterations: 3
# Simulation Time: 0.71 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 142 | Iterations: 3
# Simulation Time: 0.72 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 143 | Iterations: 3
# Simulation Time: 0.72 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 144 | Iterations: 3
# Simulation Time: 0.73 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 145 | Iterations: 3
# Simulation Time: 0.73 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 146 | Iterations: 3
# Simulation Time: 0.74 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 147 | Iterations: 3
# Simulation Time: 0.74 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 148 | Iterations: 3
# Simulation Time: 0.75 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 149 | Iterations: 3
# Simulation Time: 0.75 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 150 | Iterations: 3
# Simulation Time: 0.76 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 151 | Iterations: 3
# Simulation Time: 0.76 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 152 | Iterations: 3
# Simulation Time: 0.77 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 153 | Iterations: 3
# Simulation Time: 0.77 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 154 | Iterations: 3
# Simulation Time: 0.78 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 155 | Iterations: 3
# Simulation Time: 0.78 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 156 | Iterations: 3
# Simulation Time: 0.79 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 157 | Iterations: 3
# Simulation Time: 0.79 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 158 | Iterations: 3
# Simulation Time: 0.8 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 159 | Iterations: 3
# Simulation Time: 0.8 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 160 | Iterations: 3
# Simulation Time: 0.81 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 161 | Iterations: 3
# Simulation Time: 0.81 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 162 | Iterations: 3
# Simulation Time: 0.82 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 163 | Iterations: 3
# Simulation Time: 0.82 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 164 | Iterations: 3
# Simulation Time: 0.83 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 165 | Iterations: 3
# Simulation Time: 0.83 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 166 | Iterations: 3
# Simulation Time: 0.84 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 167 | Iterations: 3
# Simulation Time: 0.84 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 168 | Iterations: 3
# Simulation Time: 0.85 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 169 | Iterations: 3
# Simulation Time: 0.85 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 170 | Iterations: 3
# Simulation Time: 0.86 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 171 | Iterations: 3
# Simulation Time: 0.86 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 172 | Iterations: 3
# Simulation Time: 0.87 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 173 | Iterations: 3
# Simulation Time: 0.87 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 174 | Iterations: 3
# Simulation Time: 0.88 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 175 | Iterations: 3
# Simulation Time: 0.88 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 176 | Iterations: 3
# Simulation Time: 0.89 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 177 | Iterations: 3
# Simulation Time: 0.89 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 178 | Iterations: 3
# Simulation Time: 0.9 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 179 | Iterations: 3
# Simulation Time: 0.9 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 180 | Iterations: 3
# Simulation Time: 0.91 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 181 | Iterations: 3
# Simulation Time: 0.91 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 182 | Iterations: 3
# Simulation Time: 0.92 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 183 | Iterations: 3
# Simulation Time: 0.92 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 184 | Iterations: 3
# Simulation Time: 0.93 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 185 | Iterations: 3
# Simulation Time: 0.93 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 186 | Iterations: 3
# Simulation Time: 0.94 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 187 | Iterations: 3
# Simulation Time: 0.94 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 188 | Iterations: 3
# Simulation Time: 0.95 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 189 | Iterations: 3
# Simulation Time: 0.95 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 190 | Iterations: 3
# Simulation Time: 0.96 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 191 | Iterations: 3
# Simulation Time: 0.96 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 192 | Iterations: 3
# Simulation Time: 0.97 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 193 | Iterations: 3
# Simulation Time: 0.97 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 194 | Iterations: 3
# Simulation Time: 0.98 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 195 | Iterations: 3
# Simulation Time: 0.98 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 196 | Iterations: 3
# Simulation Time: 0.99 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 197 | Iterations: 3
# Simulation Time: 0.99 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 198 | Iterations: 3
# Simulation Time: 1.0 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 199 | Iterations: 3
# Simulation Time: 1.0 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 200 | Iterations: 3
# Simulation Time: 1.01 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 201 | Iterations: 3
# Simulation Time: 1.01 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 202 | Iterations: 3
# Simulation Time: 1.02 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 203 | Iterations: 3
# Simulation Time: 1.02 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 204 | Iterations: 3
# Simulation Time: 1.03 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 205 | Iterations: 3
# Simulation Time: 1.03 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 206 | Iterations: 3
# Simulation Time: 1.03 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 207 | Iterations: 3
# Simulation Time: 1.04 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 208 | Iterations: 3
# Simulation Time: 1.04 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 209 | Iterations: 3
# Simulation Time: 1.05 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 210 | Iterations: 3
# Simulation Time: 1.05 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 211 | Iterations: 3
# Simulation Time: 1.06 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 212 | Iterations: 3
# Simulation Time: 1.06 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 213 | Iterations: 3
# Simulation Time: 1.07 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 214 | Iterations: 3
# Simulation Time: 1.07 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 215 | Iterations: 3
# Simulation Time: 1.08 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 216 | Iterations: 3
# Simulation Time: 1.08 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 217 | Iterations: 3
# Simulation Time: 1.09 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 218 | Iterations: 3
# Simulation Time: 1.09 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 219 | Iterations: 3
# Simulation Time: 1.1 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 220 | Iterations: 3
# Simulation Time: 1.1 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 221 | Iterations: 3
# Simulation Time: 1.11 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 222 | Iterations: 3
# Simulation Time: 1.11 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 223 | Iterations: 3
# Simulation Time: 1.12 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 224 | Iterations: 3
# Simulation Time: 1.12 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 225 | Iterations: 3
# Simulation Time: 1.13 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 226 | Iterations: 3
# Simulation Time: 1.13 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 227 | Iterations: 3
# Simulation Time: 1.14 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 228 | Iterations: 3
# Simulation Time: 1.14 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 229 | Iterations: 3
# Simulation Time: 1.15 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 230 | Iterations: 3
# Simulation Time: 1.15 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 231 | Iterations: 3
# Simulation Time: 1.16 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 232 | Iterations: 3
# Simulation Time: 1.16 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 233 | Iterations: 3
# Simulation Time: 1.17 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 234 | Iterations: 3
# Simulation Time: 1.17 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 235 | Iterations: 3
# Simulation Time: 1.18 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 236 | Iterations: 3
# Simulation Time: 1.18 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 237 | Iterations: 3
# Simulation Time: 1.19 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 238 | Iterations: 3
# Simulation Time: 1.19 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 239 | Iterations: 3
# Simulation Time: 1.2 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 240 | Iterations: 3
# Simulation Time: 1.2 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 241 | Iterations: 3
# Simulation Time: 1.21 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 242 | Iterations: 3
# Simulation Time: 1.21 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 243 | Iterations: 3
# Simulation Time: 1.22 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 244 | Iterations: 3
# Simulation Time: 1.22 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 245 | Iterations: 3
# Simulation Time: 1.23 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 246 | Iterations: 3
# Simulation Time: 1.23 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 247 | Iterations: 3
# Simulation Time: 1.24 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 248 | Iterations: 3
# Simulation Time: 1.24 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 249 | Iterations: 3
# Simulation Time: 1.25 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 250 | Iterations: 3
# Simulation Time: 1.25 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 251 | Iterations: 3
# Simulation Time: 1.26 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 252 | Iterations: 3
# Simulation Time: 1.26 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 253 | Iterations: 3
# Simulation Time: 1.27 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 254 | Iterations: 3
# Simulation Time: 1.27 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 255 | Iterations: 3
# Simulation Time: 1.28 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 256 | Iterations: 3
# Simulation Time: 1.28 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 257 | Iterations: 3
# Simulation Time: 1.29 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 258 | Iterations: 3
# Simulation Time: 1.29 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 259 | Iterations: 3
# Simulation Time: 1.3 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 260 | Iterations: 3
# Simulation Time: 1.3 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 261 | Iterations: 3
# Simulation Time: 1.31 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 262 | Iterations: 3
# Simulation Time: 1.31 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 263 | Iterations: 3
# Simulation Time: 1.32 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 264 | Iterations: 3
# Simulation Time: 1.32 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 265 | Iterations: 3
# Simulation Time: 1.33 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 266 | Iterations: 3
# Simulation Time: 1.33 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 267 | Iterations: 3
# Simulation Time: 1.34 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 268 | Iterations: 3
# Simulation Time: 1.34 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 269 | Iterations: 3
# Simulation Time: 1.35 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 270 | Iterations: 3
# Simulation Time: 1.35 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 271 | Iterations: 3
# Simulation Time: 1.36 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 272 | Iterations: 3
# Simulation Time: 1.36 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 273 | Iterations: 3
# Simulation Time: 1.37 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 274 | Iterations: 3
# Simulation Time: 1.37 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 275 | Iterations: 3
# Simulation Time: 1.38 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 276 | Iterations: 3
# Simulation Time: 1.38 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 277 | Iterations: 3
# Simulation Time: 1.39 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 278 | Iterations: 3
# Simulation Time: 1.39 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 279 | Iterations: 3
# Simulation Time: 1.4 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 280 | Iterations: 3
# Simulation Time: 1.4 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 281 | Iterations: 3
# Simulation Time: 1.41 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 282 | Iterations: 3
# Simulation Time: 1.41 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 283 | Iterations: 3
# Simulation Time: 1.42 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 284 | Iterations: 3
# Simulation Time: 1.42 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 285 | Iterations: 3
# Simulation Time: 1.43 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 286 | Iterations: 3
# Simulation Time: 1.43 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 287 | Iterations: 3
# Simulation Time: 1.44 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 288 | Iterations: 3
# Simulation Time: 1.44 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 289 | Iterations: 3
# Simulation Time: 1.45 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 290 | Iterations: 3
# Simulation Time: 1.45 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 291 | Iterations: 3
# Simulation Time: 1.46 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 292 | Iterations: 3
# Simulation Time: 1.46 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 293 | Iterations: 3
# Simulation Time: 1.47 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 294 | Iterations: 3
# Simulation Time: 1.47 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 295 | Iterations: 3
# Simulation Time: 1.48 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 296 | Iterations: 3
# Simulation Time: 1.48 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 297 | Iterations: 3
# Simulation Time: 1.49 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 298 | Iterations: 3
# Simulation Time: 1.49 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 299 | Iterations: 3
# Simulation Time: 1.5 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 300 | Iterations: 3
# Simulation Time: 1.5 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 301 | Iterations: 3
# Simulation Time: 1.51 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 302 | Iterations: 3
# Simulation Time: 1.51 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 303 | Iterations: 3
# Simulation Time: 1.52 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 304 | Iterations: 3
# Simulation Time: 1.52 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 305 | Iterations: 3
# Simulation Time: 1.53 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 306 | Iterations: 3
# Simulation Time: 1.53 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 307 | Iterations: 3
# Simulation Time: 1.54 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 308 | Iterations: 3
# Simulation Time: 1.54 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 309 | Iterations: 3
# Simulation Time: 1.55 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 310 | Iterations: 3
# Simulation Time: 1.55 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 311 | Iterations: 3
# Simulation Time: 1.56 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 312 | Iterations: 3
# Simulation Time: 1.56 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 313 | Iterations: 3
# Simulation Time: 1.57 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 314 | Iterations: 3
# Simulation Time: 1.57 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 315 | Iterations: 3
# Simulation Time: 1.58 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 316 | Iterations: 3
# Simulation Time: 1.58 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 317 | Iterations: 3
# Simulation Time: 1.59 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 318 | Iterations: 3
# Simulation Time: 1.59 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 319 | Iterations: 3
# Simulation Time: 1.6 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 320 | Iterations: 3
# Simulation Time: 1.6 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 321 | Iterations: 3
# Simulation Time: 1.61 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 322 | Iterations: 3
# Simulation Time: 1.61 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 323 | Iterations: 3
# Simulation Time: 1.62 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 324 | Iterations: 3
# Simulation Time: 1.62 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 325 | Iterations: 3
# Simulation Time: 1.63 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 326 | Iterations: 3
# Simulation Time: 1.63 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 327 | Iterations: 3
# Simulation Time: 1.64 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 328 | Iterations: 3
# Simulation Time: 1.64 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 329 | Iterations: 3
# Simulation Time: 1.65 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 330 | Iterations: 3
# Simulation Time: 1.65 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 331 | Iterations: 3
# Simulation Time: 1.66 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 332 | Iterations: 3
# Simulation Time: 1.66 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 333 | Iterations: 3
# Simulation Time: 1.67 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 334 | Iterations: 3
# Simulation Time: 1.67 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 335 | Iterations: 3
# Simulation Time: 1.68 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 336 | Iterations: 3
# Simulation Time: 1.68 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 337 | Iterations: 3
# Simulation Time: 1.69 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 338 | Iterations: 3
# Simulation Time: 1.69 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 339 | Iterations: 3
# Simulation Time: 1.7 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 340 | Iterations: 3
# Simulation Time: 1.7 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 341 | Iterations: 3
# Simulation Time: 1.71 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 342 | Iterations: 3
# Simulation Time: 1.71 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 343 | Iterations: 3
# Simulation Time: 1.72 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 344 | Iterations: 3
# Simulation Time: 1.72 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 345 | Iterations: 3
# Simulation Time: 1.73 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 346 | Iterations: 3
# Simulation Time: 1.73 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 347 | Iterations: 3
# Simulation Time: 1.74 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 348 | Iterations: 3
# Simulation Time: 1.74 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 349 | Iterations: 3
# Simulation Time: 1.75 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 350 | Iterations: 3
# Simulation Time: 1.75 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 351 | Iterations: 3
# Simulation Time: 1.76 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 352 | Iterations: 3
# Simulation Time: 1.76 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 353 | Iterations: 3
# Simulation Time: 1.77 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 354 | Iterations: 3
# Simulation Time: 1.77 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 355 | Iterations: 3
# Simulation Time: 1.78 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 356 | Iterations: 3
# Simulation Time: 1.78 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 357 | Iterations: 3
# Simulation Time: 1.79 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 358 | Iterations: 3
# Simulation Time: 1.79 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 359 | Iterations: 3
# Simulation Time: 1.8 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 360 | Iterations: 3
# Simulation Time: 1.8 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 361 | Iterations: 3
# Simulation Time: 1.81 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 362 | Iterations: 3
# Simulation Time: 1.81 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 363 | Iterations: 3
# Simulation Time: 1.82 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 364 | Iterations: 3
# Simulation Time: 1.82 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 365 | Iterations: 3
# Simulation Time: 1.83 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 366 | Iterations: 3
# Simulation Time: 1.83 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 367 | Iterations: 3
# Simulation Time: 1.84 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 368 | Iterations: 3
# Simulation Time: 1.84 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 369 | Iterations: 3
# Simulation Time: 1.85 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 370 | Iterations: 3
# Simulation Time: 1.85 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 371 | Iterations: 3
# Simulation Time: 1.86 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 372 | Iterations: 3
# Simulation Time: 1.86 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 373 | Iterations: 3
# Simulation Time: 1.87 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 374 | Iterations: 3
# Simulation Time: 1.87 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 375 | Iterations: 3
# Simulation Time: 1.88 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 376 | Iterations: 3
# Simulation Time: 1.88 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 377 | Iterations: 3
# Simulation Time: 1.89 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 378 | Iterations: 3
# Simulation Time: 1.89 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 379 | Iterations: 3
# Simulation Time: 1.9 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 380 | Iterations: 3
# Simulation Time: 1.9 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 381 | Iterations: 3
# Simulation Time: 1.91 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 382 | Iterations: 3
# Simulation Time: 1.91 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 383 | Iterations: 3
# Simulation Time: 1.92 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 384 | Iterations: 3
# Simulation Time: 1.92 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 385 | Iterations: 3
# Simulation Time: 1.93 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 386 | Iterations: 3
# Simulation Time: 1.93 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 387 | Iterations: 3
# Simulation Time: 1.94 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 388 | Iterations: 3
# Simulation Time: 1.94 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 389 | Iterations: 3
# Simulation Time: 1.95 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 390 | Iterations: 3
# Simulation Time: 1.95 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 391 | Iterations: 3
# Simulation Time: 1.96 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 392 | Iterations: 3
# Simulation Time: 1.96 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 393 | Iterations: 3
# Simulation Time: 1.97 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 394 | Iterations: 3
# Simulation Time: 1.97 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 395 | Iterations: 3
# Simulation Time: 1.98 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 396 | Iterations: 3
# Simulation Time: 1.98 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 397 | Iterations: 3
# Simulation Time: 1.99 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 398 | Iterations: 3
# Simulation Time: 1.99 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 399 | Iterations: 3
# Simulation Time: 2.0 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 400 | Iterations: 3
# Simulation Time: 2.0 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 401 | Iterations: 3
# Simulation Time: 2.01 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 402 | Iterations: 3
# Simulation Time: 2.01 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 403 | Iterations: 3
# Simulation Time: 2.02 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 404 | Iterations: 3
# Simulation Time: 2.02 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 405 | Iterations: 3
# Simulation Time: 2.03 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 406 | Iterations: 3
# Simulation Time: 2.03 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 407 | Iterations: 3
# Simulation Time: 2.04 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 408 | Iterations: 3
# Simulation Time: 2.04 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 409 | Iterations: 3
# Simulation Time: 2.05 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 410 | Iterations: 3
# Simulation Time: 2.05 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 411 | Iterations: 3
# Simulation Time: 2.06 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 412 | Iterations: 3
# Simulation Time: 2.06 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 413 | Iterations: 3
# Simulation Time: 2.07 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 414 | Iterations: 3
# Simulation Time: 2.07 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 415 | Iterations: 3
# Simulation Time: 2.08 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 416 | Iterations: 3
# Simulation Time: 2.08 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 417 | Iterations: 3
# Simulation Time: 2.09 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 418 | Iterations: 3
# Simulation Time: 2.09 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 419 | Iterations: 3
# Simulation Time: 2.1 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 420 | Iterations: 3
# Simulation Time: 2.1 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 421 | Iterations: 3
# Simulation Time: 2.11 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 422 | Iterations: 3
# Simulation Time: 2.11 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 423 | Iterations: 3
# Simulation Time: 2.12 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 424 | Iterations: 3
# Simulation Time: 2.12 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 425 | Iterations: 3
# Simulation Time: 2.13 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 426 | Iterations: 3
# Simulation Time: 2.13 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 427 | Iterations: 3
# Simulation Time: 2.14 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 428 | Iterations: 3
# Simulation Time: 2.14 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 429 | Iterations: 3
# Simulation Time: 2.15 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 430 | Iterations: 3
# Simulation Time: 2.15 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 431 | Iterations: 3
# Simulation Time: 2.16 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 432 | Iterations: 4
# Simulation Time: 2.16 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 433 | Iterations: 4
# Simulation Time: 2.17 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 434 | Iterations: 4
# Simulation Time: 2.17 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 435 | Iterations: 4
# Simulation Time: 2.18 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 436 | Iterations: 4
# Simulation Time: 2.18 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 437 | Iterations: 4
# Simulation Time: 2.19 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 438 | Iterations: 4
# Simulation Time: 2.19 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 439 | Iterations: 4
# Simulation Time: 2.2 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 440 | Iterations: 4
# Simulation Time: 2.2 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 441 | Iterations: 4
# Simulation Time: 2.21 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 442 | Iterations: 4
# Simulation Time: 2.21 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 443 | Iterations: 4
# Simulation Time: 2.22 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 444 | Iterations: 4
# Simulation Time: 2.22 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 445 | Iterations: 4
# Simulation Time: 2.23 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 446 | Iterations: 4
# Simulation Time: 2.23 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 447 | Iterations: 3
# Simulation Time: 2.24 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 448 | Iterations: 3
# Simulation Time: 2.24 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 449 | Iterations: 3
# Simulation Time: 2.25 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 450 | Iterations: 3
# Simulation Time: 2.25 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 451 | Iterations: 3
# Simulation Time: 2.26 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 452 | Iterations: 3
# Simulation Time: 2.26 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 453 | Iterations: 3
# Simulation Time: 2.27 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 454 | Iterations: 3
# Simulation Time: 2.27 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 455 | Iterations: 3
# Simulation Time: 2.28 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 456 | Iterations: 3
# Simulation Time: 2.28 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 457 | Iterations: 3
# Simulation Time: 2.29 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 458 | Iterations: 3
# Simulation Time: 2.29 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 459 | Iterations: 3
# Simulation Time: 2.3 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 460 | Iterations: 3
# Simulation Time: 2.3 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 461 | Iterations: 3
# Simulation Time: 2.31 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 462 | Iterations: 3
# Simulation Time: 2.31 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 463 | Iterations: 3
# Simulation Time: 2.32 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 464 | Iterations: 3
# Simulation Time: 2.32 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 465 | Iterations: 3
# Simulation Time: 2.33 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 466 | Iterations: 3
# Simulation Time: 2.33 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 467 | Iterations: 3
# Simulation Time: 2.34 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 468 | Iterations: 3
# Simulation Time: 2.34 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 469 | Iterations: 3
# Simulation Time: 2.35 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 470 | Iterations: 3
# Simulation Time: 2.35 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 471 | Iterations: 4
# Simulation Time: 2.36 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 472 | Iterations: 4
# Simulation Time: 2.36 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 473 | Iterations: 4
# Simulation Time: 2.37 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 474 | Iterations: 4
# Simulation Time: 2.37 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 475 | Iterations: 4
# Simulation Time: 2.38 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 476 | Iterations: 4
# Simulation Time: 2.38 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 477 | Iterations: 4
# Simulation Time: 2.39 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 478 | Iterations: 4
# Simulation Time: 2.39 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 479 | Iterations: 4
# Simulation Time: 2.4 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 480 | Iterations: 4
# Simulation Time: 2.4 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 481 | Iterations: 4
# Simulation Time: 2.41 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 482 | Iterations: 4
# Simulation Time: 2.41 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 483 | Iterations: 4
# Simulation Time: 2.42 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 484 | Iterations: 4
# Simulation Time: 2.42 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 485 | Iterations: 4
# Simulation Time: 2.43 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 486 | Iterations: 4
# Simulation Time: 2.43 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 487 | Iterations: 4
# Simulation Time: 2.44 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 488 | Iterations: 4
# Simulation Time: 2.44 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 489 | Iterations: 4
# Simulation Time: 2.45 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 490 | Iterations: 4
# Simulation Time: 2.45 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 491 | Iterations: 4
# Simulation Time: 2.46 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 492 | Iterations: 4
# Simulation Time: 2.46 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 493 | Iterations: 4
# Simulation Time: 2.47 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 494 | Iterations: 4
# Simulation Time: 2.47 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 495 | Iterations: 4
# Simulation Time: 2.48 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 496 | Iterations: 4
# Simulation Time: 2.48 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 497 | Iterations: 4
# Simulation Time: 2.49 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 498 | Iterations: 4
# Simulation Time: 2.49 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 499 | Iterations: 4
# Simulation Time: 2.5 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 500 | Iterations: 4
# Simulation Time: 2.5 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 501 | Iterations: 4
# Simulation Time: 2.51 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 502 | Iterations: 4
# Simulation Time: 2.51 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 503 | Iterations: 4
# Simulation Time: 2.52 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 504 | Iterations: 4
# Simulation Time: 2.52 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 505 | Iterations: 4
# Simulation Time: 2.53 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 506 | Iterations: 4
# Simulation Time: 2.53 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 507 | Iterations: 4
# Simulation Time: 2.54 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 508 | Iterations: 4
# Simulation Time: 2.54 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 509 | Iterations: 4
# Simulation Time: 2.55 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 510 | Iterations: 4
# Simulation Time: 2.55 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 511 | Iterations: 4
# Simulation Time: 2.56 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 512 | Iterations: 4
# Simulation Time: 2.56 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 513 | Iterations: 4
# Simulation Time: 2.57 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 514 | Iterations: 4
# Simulation Time: 2.57 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 515 | Iterations: 4
# Simulation Time: 2.58 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 516 | Iterations: 4
# Simulation Time: 2.58 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 517 | Iterations: 4
# Simulation Time: 2.59 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 518 | Iterations: 3
# Simulation Time: 2.59 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 519 | Iterations: 3
# Simulation Time: 2.6 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 520 | Iterations: 3
# Simulation Time: 2.6 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 521 | Iterations: 3
# Simulation Time: 2.61 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 522 | Iterations: 3
# Simulation Time: 2.61 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 523 | Iterations: 3
# Simulation Time: 2.62 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 524 | Iterations: 3
# Simulation Time: 2.62 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 525 | Iterations: 3
# Simulation Time: 2.63 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 526 | Iterations: 3
# Simulation Time: 2.63 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 527 | Iterations: 3
# Simulation Time: 2.64 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 528 | Iterations: 3
# Simulation Time: 2.64 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 529 | Iterations: 3
# Simulation Time: 2.65 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 530 | Iterations: 3
# Simulation Time: 2.65 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 531 | Iterations: 3
# Simulation Time: 2.66 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 532 | Iterations: 3
# Simulation Time: 2.66 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 533 | Iterations: 3
# Simulation Time: 2.67 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 534 | Iterations: 3
# Simulation Time: 2.67 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 535 | Iterations: 3
# Simulation Time: 2.68 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 536 | Iterations: 3
# Simulation Time: 2.68 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 537 | Iterations: 3
# Simulation Time: 2.69 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 538 | Iterations: 3
# Simulation Time: 2.69 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 539 | Iterations: 3
# Simulation Time: 2.7 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 540 | Iterations: 3
# Simulation Time: 2.7 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 541 | Iterations: 3
# Simulation Time: 2.71 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 542 | Iterations: 3
# Simulation Time: 2.71 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 543 | Iterations: 3
# Simulation Time: 2.72 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 544 | Iterations: 3
# Simulation Time: 2.72 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 545 | Iterations: 3
# Simulation Time: 2.73 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 546 | Iterations: 3
# Simulation Time: 2.73 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 547 | Iterations: 3
# Simulation Time: 2.74 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 548 | Iterations: 3
# Simulation Time: 2.74 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 549 | Iterations: 3
# Simulation Time: 2.75 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 550 | Iterations: 3
# Simulation Time: 2.75 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 551 | Iterations: 3
# Simulation Time: 2.76 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 552 | Iterations: 3
# Simulation Time: 2.76 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 553 | Iterations: 3
# ...
#
# Step: Evolve |   Increment: 619 | Iterations: 3
# Simulation Time: 3.1 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 620 | Iterations: 3
# Simulation Time: 3.1 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 621 | Iterations: 3
# Simulation Time: 3.11 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 622 | Iterations: 3
# Simulation Time: 3.11 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 623 | Iterations: 3
# Simulation Time: 3.12 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 624 | Iterations: 3
# Simulation Time: 3.12 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 625 | Iterations: 3
# Simulation Time: 3.13 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 626 | Iterations: 3
# Simulation Time: 3.13 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 627 | Iterations: 3
# Simulation Time: 3.14 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 628 | Iterations: 3
# Simulation Time: 3.14 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 629 | Iterations: 3
# Simulation Time: 3.15 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 630 | Iterations: 3
# Simulation Time: 3.15 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 631 | Iterations: 3
# Simulation Time: 3.16 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 632 | Iterations: 3
# Simulation Time: 3.16 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 633 | Iterations: 3
# Simulation Time: 3.17 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 634 | Iterations: 3
# Simulation Time: 3.17 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 635 | Iterations: 3
# Simulation Time: 3.18 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 636 | Iterations: 3
# Simulation Time: 3.18 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 637 | Iterations: 3
# Simulation Time: 3.19 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 638 | Iterations: 3
# Simulation Time: 3.19 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 639 | Iterations: 3
# Simulation Time: 3.2 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 640 | Iterations: 3
# Simulation Time: 3.2 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 641 | Iterations: 3
# Simulation Time: 3.21 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 642 | Iterations: 3
# Simulation Time: 3.21 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 643 | Iterations: 3
# Simulation Time: 3.22 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 644 | Iterations: 3
# Simulation Time: 3.22 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 645 | Iterations: 3
# Simulation Time: 3.23 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 646 | Iterations: 3
# Simulation Time: 3.23 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 647 | Iterations: 3
# Simulation Time: 3.24 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 648 | Iterations: 3
# Simulation Time: 3.24 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 649 | Iterations: 3
# Simulation Time: 3.25 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 650 | Iterations: 3
# Simulation Time: 3.25 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 651 | Iterations: 3
# Simulation Time: 3.26 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 652 | Iterations: 3
# Simulation Time: 3.26 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 653 | Iterations: 3
# Simulation Time: 3.27 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 654 | Iterations: 3
# Simulation Time: 3.27 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 655 | Iterations: 3
# Simulation Time: 3.28 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 656 | Iterations: 3
# Simulation Time: 3.28 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 657 | Iterations: 3
# Simulation Time: 3.29 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 658 | Iterations: 3
# Simulation Time: 3.29 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 659 | Iterations: 3
# Simulation Time: 3.3 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 660 | Iterations: 3
# Simulation Time: 3.3 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 661 | Iterations: 3
# Simulation Time: 3.31 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 662 | Iterations: 3
# Simulation Time: 3.31 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 663 | Iterations: 3
# Simulation Time: 3.32 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 664 | Iterations: 3
# Simulation Time: 3.32 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 665 | Iterations: 3
# Simulation Time: 3.33 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 666 | Iterations: 3
# Simulation Time: 3.33 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 667 | Iterations: 3
# Simulation Time: 3.34 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 668 | Iterations: 3
# Simulation Time: 3.34 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 669 | Iterations: 3
# Simulation Time: 3.35 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 670 | Iterations: 3
# Simulation Time: 3.35 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 671 | Iterations: 3
# Simulation Time: 3.36 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 672 | Iterations: 3
# Simulation Time: 3.36 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 673 | Iterations: 3
# Simulation Time: 3.37 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 674 | Iterations: 3
# Simulation Time: 3.37 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 675 | Iterations: 3
# Simulation Time: 3.38 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 676 | Iterations: 3
# Simulation Time: 3.38 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 677 | Iterations: 3
# Simulation Time: 3.39 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 678 | Iterations: 3
# Simulation Time: 3.39 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 679 | Iterations: 3
# Simulation Time: 3.4 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 680 | Iterations: 3
# Simulation Time: 3.4 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 681 | Iterations: 3
# Simulation Time: 3.41 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 682 | Iterations: 3
# Simulation Time: 3.41 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 683 | Iterations: 3
# Simulation Time: 3.42 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 684 | Iterations: 3
# Simulation Time: 3.42 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 685 | Iterations: 3
# Simulation Time: 3.43 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 686 | Iterations: 3
# Simulation Time: 3.43 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 687 | Iterations: 3
# Simulation Time: 3.44 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 688 | Iterations: 3
# Simulation Time: 3.44 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 689 | Iterations: 3
# Simulation Time: 3.45 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 690 | Iterations: 3
# Simulation Time: 3.45 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 691 | Iterations: 3
# Simulation Time: 3.46 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 692 | Iterations: 3
# Simulation Time: 3.46 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 693 | Iterations: 3
# Simulation Time: 3.47 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 694 | Iterations: 3
# Simulation Time: 3.47 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 695 | Iterations: 3
# Simulation Time: 3.48 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 696 | Iterations: 3
# Simulation Time: 3.48 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 697 | Iterations: 3
# Simulation Time: 3.49 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 698 | Iterations: 3
# Simulation Time: 3.49 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 699 | Iterations: 3
# Simulation Time: 3.5 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 700 | Iterations: 3
# Simulation Time: 3.5 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 701 | Iterations: 3
# Simulation Time: 3.51 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 702 | Iterations: 3
# Simulation Time: 3.51 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 703 | Iterations: 3
# Simulation Time: 3.52 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 704 | Iterations: 3
# Simulation Time: 3.52 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 705 | Iterations: 3
# Simulation Time: 3.53 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 706 | Iterations: 3
# Simulation Time: 3.53 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 707 | Iterations: 3
# Simulation Time: 3.54 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 708 | Iterations: 3
# Simulation Time: 3.54 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 709 | Iterations: 3
# Simulation Time: 3.55 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 710 | Iterations: 3
# Simulation Time: 3.55 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 711 | Iterations: 3
# Simulation Time: 3.56 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 712 | Iterations: 3
# Simulation Time: 3.56 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 713 | Iterations: 3
# Simulation Time: 3.57 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 714 | Iterations: 3
# Simulation Time: 3.57 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 715 | Iterations: 3
# Simulation Time: 3.58 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 716 | Iterations: 3
# Simulation Time: 3.58 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 717 | Iterations: 3
# Simulation Time: 3.59 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 718 | Iterations: 3
# Simulation Time: 3.59 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 719 | Iterations: 3
# Simulation Time: 3.6 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 720 | Iterations: 3
# Simulation Time: 3.6 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 721 | Iterations: 3
# Simulation Time: 3.61 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 722 | Iterations: 3
# Simulation Time: 3.61 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 723 | Iterations: 3
# Simulation Time: 3.62 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 724 | Iterations: 3
# Simulation Time: 3.62 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 725 | Iterations: 3
# Simulation Time: 3.63 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 726 | Iterations: 3
# Simulation Time: 3.63 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 727 | Iterations: 3
# Simulation Time: 3.64 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 728 | Iterations: 3
# Simulation Time: 3.64 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 729 | Iterations: 3
# Simulation Time: 3.65 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 730 | Iterations: 3
# Simulation Time: 3.65 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 731 | Iterations: 3
# Simulation Time: 3.66 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 732 | Iterations: 3
# Simulation Time: 3.66 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 733 | Iterations: 3
# Simulation Time: 3.67 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 734 | Iterations: 3
# Simulation Time: 3.67 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 735 | Iterations: 3
# Simulation Time: 3.68 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 736 | Iterations: 3
# Simulation Time: 3.68 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 737 | Iterations: 3
# Simulation Time: 3.69 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 738 | Iterations: 3
# Simulation Time: 3.69 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 739 | Iterations: 3
# Simulation Time: 3.7 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 740 | Iterations: 3
# Simulation Time: 3.7 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 741 | Iterations: 3
# Simulation Time: 3.71 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 742 | Iterations: 3
# Simulation Time: 3.71 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 743 | Iterations: 3
# Simulation Time: 3.72 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 744 | Iterations: 3
# Simulation Time: 3.72 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 745 | Iterations: 3
# Simulation Time: 3.73 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 746 | Iterations: 3
# Simulation Time: 3.73 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 747 | Iterations: 3
# Simulation Time: 3.74 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 748 | Iterations: 3
# Simulation Time: 3.74 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 749 | Iterations: 3
# Simulation Time: 3.75 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 750 | Iterations: 3
# Simulation Time: 3.75 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 751 | Iterations: 3
# Simulation Time: 3.76 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 752 | Iterations: 3
# Simulation Time: 3.76 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 753 | Iterations: 3
# Simulation Time: 3.77 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 754 | Iterations: 3
# Simulation Time: 3.77 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 755 | Iterations: 3
# Simulation Time: 3.78 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 756 | Iterations: 3
# Simulation Time: 3.78 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 757 | Iterations: 3
# Simulation Time: 3.79 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 758 | Iterations: 3
# Simulation Time: 3.79 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 759 | Iterations: 3
# Simulation Time: 3.8 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 760 | Iterations: 3
# Simulation Time: 3.8 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 761 | Iterations: 3
# Simulation Time: 3.81 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 762 | Iterations: 3
# Simulation Time: 3.81 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 763 | Iterations: 3
# Simulation Time: 3.82 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 764 | Iterations: 3
# Simulation Time: 3.82 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 765 | Iterations: 3
# Simulation Time: 3.83 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 766 | Iterations: 3
# Simulation Time: 3.83 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 767 | Iterations: 3
# Simulation Time: 3.84 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 768 | Iterations: 3
# Simulation Time: 3.84 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 769 | Iterations: 3
# Simulation Time: 3.85 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 770 | Iterations: 3
# Simulation Time: 3.85 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 771 | Iterations: 3
# Simulation Time: 3.86 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 772 | Iterations: 3
# Simulation Time: 3.86 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 773 | Iterations: 3
# Simulation Time: 3.87 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 774 | Iterations: 3
# Simulation Time: 3.87 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 775 | Iterations: 3
# Simulation Time: 3.88 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 776 | Iterations: 3
# Simulation Time: 3.88 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 777 | Iterations: 3
# Simulation Time: 3.89 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 778 | Iterations: 3
# Simulation Time: 3.89 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 779 | Iterations: 3
# Simulation Time: 3.9 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 780 | Iterations: 3
# Simulation Time: 3.9 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 781 | Iterations: 3
# Simulation Time: 3.91 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 782 | Iterations: 3
# Simulation Time: 3.91 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 783 | Iterations: 3
# Simulation Time: 3.92 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 784 | Iterations: 3
# Simulation Time: 3.92 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 785 | Iterations: 3
# Simulation Time: 3.93 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 786 | Iterations: 3
# Simulation Time: 3.93 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 787 | Iterations: 3
# Simulation Time: 3.94 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 788 | Iterations: 3
# Simulation Time: 3.94 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 789 | Iterations: 3
# Simulation Time: 3.95 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 790 | Iterations: 3
# Simulation Time: 3.95 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 791 | Iterations: 3
# Simulation Time: 3.96 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 792 | Iterations: 3
# Simulation Time: 3.96 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 793 | Iterations: 3
# Simulation Time: 3.97 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 794 | Iterations: 3
# Simulation Time: 3.97 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 795 | Iterations: 3
# Simulation Time: 3.98 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 796 | Iterations: 3
# Simulation Time: 3.98 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 797 | Iterations: 3
# Simulation Time: 3.99 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 798 | Iterations: 3
# Simulation Time: 3.99 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 799 | Iterations: 3
# Simulation Time: 4.0 s | dt: 0.005 s
#
# Step: Evolve |   Increment: 800 | Iterations: 3
# Simulation Time: 4.0 s | dt: 0.005 s
#
# ------------------------------------
# Simulation End
# ------------------------------------
# Total Time: 0:00:41.411311
# ------------------------------------
