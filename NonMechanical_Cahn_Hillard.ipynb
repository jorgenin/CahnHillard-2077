# %% [markdown]
# # Code for Cahn-Hilliard phase separation without mechanical coupling.
#
# ## 2D phase separation study.
#
#
# Degrees of freedom:
#   - scalar chemical potential: we use normalized  mu = mu/RT
#   - species concentration:  we use normalized  c= Omega*cmat
#
# ### Units:
# - Length: um
# - Mass: kg
# - Time: s
# - Amount of substance: pmol
# - Temperature: K
# - Mass density: kg/um^3
# - Force: uN
# - Stress: MPa
# - Energy: pJ
# - Species concentration: pmol/um^3
# - Chemical potential: pJ/pmol
# - Molar volume: um^3/pmol
# - Species diffusivity: um^2/s
# - Boltzmann Constant: 1.38E-11 pJ/K
# - Gas constant: 8.314  pJ/(pmol K)
#
# ### By
#   Eric Stewart      and      Lallit Anand
# ericstew@mit.edu            anand@mit.edu
#
# October 2023
#
# Modified for FenicsX by Jorge Nin
# jorgenin@mit.edu

# %%
import numpy as np


from mpi4py import MPI
from petsc4py import PETSc

from dolfinx import fem, mesh, io, plot, log
from dolfinx.fem import Constant, dirichletbc, Function, FunctionSpace, Expression
from dolfinx.fem.petsc import NonlinearProblem
from dolfinx.nls.petsc import NewtonSolver
from dolfinx.io import VTXWriter
import ufl
from ufl import (
    TestFunction,
    TrialFunction,
    Identity,
    grad,
    det,
    div,
    dev,
    inv,
    tr,
    sqrt,
    conditional,
    gt,
    dx,
    inner,
    derivative,
    dot,
    ln,
    split,
    tanh,
    as_tensor,
    as_vector,
    ge
)
from datetime import datetime
from dolfinx.plot import vtk_mesh

import pyvista

pyvista.set_jupyter_backend("client")
## Define temporal parameters
import random

# %% [markdown]
# # DEFINE GEOMETRY

# %%
problemName = "Canh Hillard"

# Square edge length
L0 = 0.8  # 800 nm box, after Di Leo et al. (2014)

# Number of elements along each side
N = 100

# Create square mesh
domain = mesh.create_rectangle(MPI.COMM_WORLD, [(0, 0), (L0, L0)], [N, N])

# %% [markdown]
# ## Visualize the geometry

# %%
#sysctl -a|grep "\.shm"

plotter = pyvista.Plotter()
vtkdata = vtk_mesh(domain, domain.topology.dim)
grid = pyvista.UnstructuredGrid(*vtkdata)
actor = plotter.add_mesh(grid, show_edges=True)
plotter.show()
plotter.close()
# Out:
# Widget(value="<iframe src='http://localhost:55463/index.html?ui=P_0x2a4e09310_0&reconnect=auto' style='width: …

# %% [markdown]
# # Periodicity

# %%
def inside(self, x, on_boundary):
    # return True if on left or bottom boundary AND NOT
    # on one of the two corners (0, L0) and (L0, 0)
    return bool(
        (np.isclose(x[0], 0) or np.isclose(x[1], 0))
        and (
            not (
                (np.isclose(x[0], 0) and np.isclose(x[1], L0))
                or (np.isclose(x[0], L0) and np.isclose(x[1], 0))
            )
        )
        and on_boundary
    )


def map(self, x, y):
    if np.isclose(x[0], L0) and np.isclose(x[1], L0):
        y[0] = x[0] - L0
        y[1] = x[1] - L0
    elif np.isclose(x[0], L0):
        y[0] = x[0] - L0
        y[1] = x[1]
    else:  # np.isclose(x[1], L0)
        y[0] = x[0]
        y[1] = x[1] - L0

# %% [markdown]
# # Material Parameters

# %%
# Material parameters after Di Leo et al. (2014)
#
Omega = Constant(domain, 4.05)  # Molar volume, um^3/pmol
D = Constant(domain, 1e-2)  # Diffusivity, um^2/s
chi = Constant(domain, 3.0)  # Phase parameter, (-)
cMax = Constant(domain, 2.29e-2)  # Saturation concentration, pmol/um^3
lam = Constant(domain, 5.5749e-1)  # Interface parameter, (pJ/pmol) um^2
theta0 = Constant(domain, 298.0)  # Reference temperature, K
R_gas = Constant(domain, 8.3145)  # Gas constant, pJ/(pmol K)

RT = R_gas * theta0

# %% [markdown]
# # Simulation Time Control

# %%
t = 0.0  # initialization of time
Ttot = 4  # total simulation time
dt = 0.01  # Initial time step size, here we will use adaptive time-stepping

# %% [markdown]
# # Function Spaces

# %%
U2 = ufl.VectorElement("Lagrange", domain.ufl_cell(), 2)  # For displacement
P1 = ufl.FiniteElement("Lagrange", domain.ufl_cell(), 1)  # For  pressure
# For  normalized chemical potential
# and  normalized species concentration

TH = ufl.MixedElement([P1, P1])  # Taylor-Hood style mixed element
ME = FunctionSpace(domain, TH)  # Total space for all DOFs
x = ufl.SpatialCoordinate(domain)

# %%
# Define trial functions
w = Function(ME)
mu, c = split(w)  # chemical potential  mu, concentration c

# A copy of functions to store values in the previous step
w_old = Function(ME)
mu_old, c_old = split(w_old)

# Define test functions
w_test = TestFunction(ME)
mu_test, c_test = split(w_test)

# Define trial functions needed for automatic differentiation
dw = TrialFunction(ME)

# %%
np.random.seed(2 + MPI.COMM_WORLD.Get_rank())

# Some quick definitions to init random values
V, _ = ME.sub(0).collapse()
cBar_rand = Function(V)
cBar_rand.interpolate(
    lambda x: 0.63 + 0.05 * (0.5 - np.random.rand(x.shape[1]))
)  # Create a nice random value we can use
fc_rand = RT * (
    ln(cBar_rand / (1 - cBar_rand)) + chi * (1 - 2 * cBar_rand)
)  # use that relation to initate the two different sub expressions


# Concentration Expressoin
concentration = Expression(Omega * cMax * cBar_rand, ME.sub(1).element.interpolation_points())
w.sub(1).interpolate( concentration )

chemical_potential = Expression(fc_rand / RT, ME.sub(0).element.interpolation_points())
w.sub(0).interpolate(chemical_potential)

w_old.x.array[:] = w.x.array

# %% [markdown]
# # Subroutines

# %%
"""
For 2D plane strain:
"""


# Gradient of vector field u
def pe_grad_vector(u):
    grad_u = grad(u)
    return as_tensor(
        [[grad_u[0, 0], grad_u[0, 1], 0], [grad_u[1, 0], grad_u[1, 1], 0], [0, 0, 0]]
    )


# Gradient of scalar field y
# (just need an extra zero for dimensions to work out)
def pe_grad_scalar(y):
    grad_y = grad(y)
    return as_vector([grad_y[0], grad_y[1], 0.0])


# ------------------------------------------------------------------------------
# Species flux
def Flux_calc(mu, c):
    #
    cBar = c / (Omega * cMax)  # normalized concentration
    #
    Mob = (D * c) / (Omega * RT) * (1 - cBar)
    #
    Jmat = -RT * Mob * pe_grad_scalar(mu)
    return Jmat


# Calculate the f^c term
def fc_calc(mu, c):
    #
    cBar = c / (Omega * cMax)  # normalized concentration
    #
    fc = RT * (ln(cBar / (1 - cBar)) + chi * (1 - 2 * cBar))
    #
    return fc


# Eigenvalue decomposition of a 2D tensor
def eigs(T):
    # Compute eigenvalues
    lambda1_0 = (
        T[0, 0] / 2
        + T[1, 1] / 2
        - sqrt(
            T[0, 0] ** 2 - 2 * T[0, 0] * T[1, 1] + 4 * T[0, 1] * T[1, 0] + T[1, 1] ** 2
        )
        / 2
    )
    lambda2_0 = (
        T[0, 0] / 2
        + T[1, 1] / 2
        + sqrt(
            T[0, 0] ** 2 - 2 * T[0, 0] * T[1, 1] + 4 * T[0, 1] * T[1, 0] + T[1, 1] ** 2
        )
        / 2
    )

    # Compute eigenvectors
    v11 = -T[1, 1] + lambda1_0
    v12 = T[1, 0]

    v21 = -T[1, 1] + lambda2_0
    v22 = T[1, 0]

    vec1_0 = as_vector([v11, v12])
    vec2_0 = as_vector([v21, v22])
    
    # Normalize eigenvectors
    vec1_0 = vec1_0 / sqrt(dot(vec1_0, vec1_0))
    vec2_0 = vec2_0 / sqrt(dot(vec2_0, vec2_0))

    # Reorder eigenvectors and eigenvalues
    vec1 = conditional(ge(lambda1_0, lambda2_0), vec1_0, vec2_0)
    vec2 = conditional(ge(lambda1_0, lambda2_0), vec2_0, vec1_0)

    lambda1 = conditional(ge(lambda1_0, lambda2_0), lambda1_0, lambda2_0)
    lambda2 = conditional(ge(lambda1_0, lambda2_0), lambda2_0, lambda1_0)

    return lambda1, lambda2, vec1, vec2

# %% [markdown]
# # Kinematics and constitutive relations

# %%
# Calculate the normalized concentration cBar
cBar = c/(Omega*cMax) # normalized concentration

# Calculate the Species flux
Jmat = Flux_calc(mu, c)

# Calculate the f^c term 
fc = fc_calc(mu, c)

# %% [markdown]
# # Weak Forms

# %%
# Residuals:
# Res_0: Balance of mass   (test fxn: mu)
# Res_1: chemical potential (test fxn: c)
dx = ufl.dx(metadata={"quadrature_degree": 4})

# Time step field, constant within body
dk = Constant(domain,dt)

# The weak form for the mass balance of mobile species    
Res_0 = dot((c - c_old)/dk, mu_test)*dx \
        -  Omega*dot(Jmat , pe_grad_scalar(mu_test) )*dx      

# The weak form for the concentration
Res_1 = dot(mu - fc/RT, c_test)*dx \
        -  dot( (lam/RT)*pe_grad_scalar(cBar), pe_grad_scalar(c_test))*dx
        
# Total weak form
Res = Res_0 + Res_1

# Automatic differentiation tangent:
a = derivative(Res, w, dw)

# %% [markdown]
# # Setup Output Files

# %%
U1 = ufl.VectorElement("Lagrange", domain.ufl_cell(), 1)
V2 = fem.FunctionSpace(domain, U1)#Vector function space
V1 = fem.FunctionSpace(domain, P1)#Scalar function space

mu_vis = Function(V1)
mu_vis.name = "mu"
mu_expr = Expression(mu,V1.element.interpolation_points())

c_vis = Function(V1)
c_vis.name = "c"
c_expr = Expression(c,V1.element.interpolation_points())

vtk = VTXWriter(domain.comm,"results/"+problemName+".bp", [mu_vis,c_vis], engine="BP4" )

def interp_and_save(t, file):
   
    mu_vis.interpolate(mu_expr)
    c_vis.interpolate(c_expr)

    file.write(t)

# %% [markdown]
# # Boundary Conditions

# %%
# Nothing! Just let the system evolve on its own.
bcs = []

# %% [markdown]
# # SETUP NONLINEAR PROBLEM

# %%
import os
step = "Swell"
jit_options ={"cffi_extra_compile_args":["-O3","-ffast-math"]}

problem = NonlinearProblem(Res, w, bcs, a)


solver = NewtonSolver(MPI.COMM_WORLD, problem)
solver.convergence_criterion = "incremental"
solver.rtol = 1e-8
solver.atol = 1e-8
solver.max_it = 50
solver.report = True


ksp = solver.krylov_solver
opts = PETSc.Options()
option_prefix = ksp.getOptionsPrefix()
opts[f"{option_prefix}ksp_max_it"] = 30
opts[f"{option_prefix}ksp_type"] = "gmres"
opts[f"{option_prefix}pc_type"] = "ksp"
ksp.setFromOptions()

startTime = datetime.now()
print("------------------------------------")
print("Simulation Start")
print("------------------------------------")

step = "Evolve"

#if os.path.exists("results/"+problemName+".bp"):
#    os.remove("results/"+problemName+".xdmf")
#    os.remove("results/"+problemName+".h5")

#vtk.write_mesh(domain)
t = 0.0

interp_and_save(t, vtk)
ii = 0
bisection_count = 0
while t < Ttot:
    # increment time
    t += float(dk) 
    # increment counter
    ii +=1
    

    # Solve the problem
    try:
        (iter, converged) = solver.solve(w)
        
        w.x.scatter_forward()
        
        
        
        w_old.x.array[:] = w.x.array
        
        interp_and_save(t, vtk)
        if ii % 1 == 0:
            now = datetime.now()
            current_time = now.strftime("%H:%M:%S")
            print("Step: {} |   Increment: {} | Iterations: {}".format(step, ii, iter))
            print("Simulation Time: {} s | dt: {} s".format(round(t, 2), round(dt, 3)))
            print()
        
        if iter <= 2:
            dt = 1.5 * dt
            dk.value = dt
        # If the newton solver takes 5 or more iterations,
        # decrease the time step by a factor of 2:
        elif iter >= 5:
            dt = dt / 2
            dk.value =dt

        #Reset Biseciton Counter
        bisection_count = 0
        
    except: # Break the loop if solver fails
        bisection_count += 1
        
        if bisection_count > 5:
            print("Error: Too many bisections")
            break
        
        print( "Error Halfing Time Step")
        t = t - float(dk)
        dt = dt / 2
        dk.value = dt
        print(f"New Time Step: {dt}")
        w.x.array[:] = w_old.x.array
        

#End Analysis
vtk.close()
endTime = datetime.now()
print("------------------------------------")
print("Simulation End")
print("------------------------------------")
print("Total Time: {}".format(endTime - startTime))
print("------------------------------------")
# Out:
# ------------------------------------
# Simulation Start
# ------------------------------------
# Step: Evolve |   Increment: 1 | Iterations: 4
# Simulation Time: 0.01 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 2 | Iterations: 3
# Simulation Time: 0.02 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 3 | Iterations: 3
# Simulation Time: 0.03 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 4 | Iterations: 3
# Simulation Time: 0.04 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 5 | Iterations: 3
# Simulation Time: 0.05 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 6 | Iterations: 3
# Simulation Time: 0.06 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 7 | Iterations: 3
# Simulation Time: 0.07 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 8 | Iterations: 3
# Simulation Time: 0.08 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 9 | Iterations: 3
# Simulation Time: 0.09 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 10 | Iterations: 3
# Simulation Time: 0.1 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 11 | Iterations: 3
# Simulation Time: 0.11 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 12 | Iterations: 3
# Simulation Time: 0.12 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 13 | Iterations: 3
# Simulation Time: 0.13 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 14 | Iterations: 3
# Simulation Time: 0.14 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 15 | Iterations: 3
# Simulation Time: 0.15 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 16 | Iterations: 3
# Simulation Time: 0.16 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 17 | Iterations: 3
# Simulation Time: 0.17 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 18 | Iterations: 3
# Simulation Time: 0.18 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 19 | Iterations: 3
# Simulation Time: 0.19 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 20 | Iterations: 3
# Simulation Time: 0.2 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 21 | Iterations: 3
# Simulation Time: 0.21 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 22 | Iterations: 3
# Simulation Time: 0.22 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 23 | Iterations: 3
# Simulation Time: 0.23 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 24 | Iterations: 3
# Simulation Time: 0.24 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 25 | Iterations: 3
# Simulation Time: 0.25 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 26 | Iterations: 3
# Simulation Time: 0.26 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 27 | Iterations: 3
# Simulation Time: 0.27 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 28 | Iterations: 3
# Simulation Time: 0.28 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 29 | Iterations: 3
# Simulation Time: 0.29 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 30 | Iterations: 3
# Simulation Time: 0.3 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 31 | Iterations: 3
# Simulation Time: 0.31 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 32 | Iterations: 3
# Simulation Time: 0.32 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 33 | Iterations: 3
# Simulation Time: 0.33 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 34 | Iterations: 3
# Simulation Time: 0.34 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 35 | Iterations: 3
# Simulation Time: 0.35 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 36 | Iterations: 4
# Simulation Time: 0.36 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 37 | Iterations: 4
# Simulation Time: 0.37 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 38 | Iterations: 4
# Simulation Time: 0.38 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 39 | Iterations: 4
# Simulation Time: 0.39 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 40 | Iterations: 4
# Simulation Time: 0.4 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 41 | Iterations: 4
# Simulation Time: 0.41 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 42 | Iterations: 4
# Simulation Time: 0.42 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 43 | Iterations: 4
# Simulation Time: 0.43 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 44 | Iterations: 4
# Simulation Time: 0.44 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 45 | Iterations: 4
# Simulation Time: 0.45 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 46 | Iterations: 4
# Simulation Time: 0.46 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 47 | Iterations: 4
# Simulation Time: 0.47 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 48 | Iterations: 4
# Simulation Time: 0.48 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 49 | Iterations: 4
# Simulation Time: 0.49 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 50 | Iterations: 4
# Simulation Time: 0.5 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 51 | Iterations: 4
# Simulation Time: 0.51 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 52 | Iterations: 4
# Simulation Time: 0.52 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 53 | Iterations: 4
# Simulation Time: 0.53 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 54 | Iterations: 4
# Simulation Time: 0.54 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 55 | Iterations: 4
# Simulation Time: 0.55 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 56 | Iterations: 4
# Simulation Time: 0.56 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 57 | Iterations: 4
# Simulation Time: 0.57 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 58 | Iterations: 4
# Simulation Time: 0.58 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 59 | Iterations: 4
# Simulation Time: 0.59 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 60 | Iterations: 4
# Simulation Time: 0.6 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 61 | Iterations: 4
# Simulation Time: 0.61 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 62 | Iterations: 4
# Simulation Time: 0.62 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 63 | Iterations: 4
# Simulation Time: 0.63 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 64 | Iterations: 4
# Simulation Time: 0.64 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 65 | Iterations: 4
# Simulation Time: 0.65 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 66 | Iterations: 4
# Simulation Time: 0.66 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 67 | Iterations: 4
# Simulation Time: 0.67 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 68 | Iterations: 4
# Simulation Time: 0.68 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 69 | Iterations: 4
# Simulation Time: 0.69 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 70 | Iterations: 4
# Simulation Time: 0.7 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 71 | Iterations: 4
# Simulation Time: 0.71 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 72 | Iterations: 4
# Simulation Time: 0.72 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 73 | Iterations: 4
# Simulation Time: 0.73 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 74 | Iterations: 4
# Simulation Time: 0.74 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 75 | Iterations: 4
# Simulation Time: 0.75 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 76 | Iterations: 4
# Simulation Time: 0.76 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 77 | Iterations: 4
# Simulation Time: 0.77 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 78 | Iterations: 4
# Simulation Time: 0.78 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 79 | Iterations: 4
# Simulation Time: 0.79 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 80 | Iterations: 4
# Simulation Time: 0.8 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 81 | Iterations: 4
# Simulation Time: 0.81 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 82 | Iterations: 4
# Simulation Time: 0.82 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 83 | Iterations: 4
# Simulation Time: 0.83 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 84 | Iterations: 4
# Simulation Time: 0.84 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 85 | Iterations: 4
# Simulation Time: 0.85 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 86 | Iterations: 4
# Simulation Time: 0.86 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 87 | Iterations: 4
# Simulation Time: 0.87 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 88 | Iterations: 4
# Simulation Time: 0.88 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 89 | Iterations: 4
# Simulation Time: 0.89 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 90 | Iterations: 4
# Simulation Time: 0.9 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 91 | Iterations: 4
# Simulation Time: 0.91 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 92 | Iterations: 4
# Simulation Time: 0.92 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 93 | Iterations: 4
# Simulation Time: 0.93 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 94 | Iterations: 4
# Simulation Time: 0.94 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 95 | Iterations: 4
# Simulation Time: 0.95 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 96 | Iterations: 4
# Simulation Time: 0.96 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 97 | Iterations: 4
# Simulation Time: 0.97 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 98 | Iterations: 4
# Simulation Time: 0.98 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 99 | Iterations: 4
# Simulation Time: 0.99 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 100 | Iterations: 4
# Simulation Time: 1.0 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 101 | Iterations: 4
# Simulation Time: 1.01 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 102 | Iterations: 4
# Simulation Time: 1.02 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 103 | Iterations: 4
# Simulation Time: 1.03 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 104 | Iterations: 4
# Simulation Time: 1.04 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 105 | Iterations: 4
# Simulation Time: 1.05 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 106 | Iterations: 4
# Simulation Time: 1.06 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 107 | Iterations: 4
# Simulation Time: 1.07 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 108 | Iterations: 4
# Simulation Time: 1.08 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 109 | Iterations: 4
# Simulation Time: 1.09 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 110 | Iterations: 4
# Simulation Time: 1.1 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 111 | Iterations: 4
# Simulation Time: 1.11 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 112 | Iterations: 4
# Simulation Time: 1.12 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 113 | Iterations: 4
# Simulation Time: 1.13 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 114 | Iterations: 4
# Simulation Time: 1.14 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 115 | Iterations: 4
# Simulation Time: 1.15 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 116 | Iterations: 4
# Simulation Time: 1.16 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 117 | Iterations: 4
# Simulation Time: 1.17 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 118 | Iterations: 4
# Simulation Time: 1.18 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 119 | Iterations: 4
# Simulation Time: 1.19 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 120 | Iterations: 4
# Simulation Time: 1.2 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 121 | Iterations: 4
# Simulation Time: 1.21 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 122 | Iterations: 4
# Simulation Time: 1.22 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 123 | Iterations: 4
# Simulation Time: 1.23 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 124 | Iterations: 4
# Simulation Time: 1.24 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 125 | Iterations: 4
# Simulation Time: 1.25 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 126 | Iterations: 4
# Simulation Time: 1.26 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 127 | Iterations: 4
# Simulation Time: 1.27 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 128 | Iterations: 4
# Simulation Time: 1.28 s | dt: 0.01 s
#
# Step: Evolve |   Increment: 129 | Iterations: 4
# Simulation Time: 1.29 s | dt: 0.01 s
#
# Error Halfing Time Step
# New Time Step: 0.005
# Error Halfing Time Step
# New Time Step: 0.0025
# Error Halfing Time Step
# New Time Step: 0.00125
# Error Halfing Time Step
# New Time Step: 0.000625
# Error Halfing Time Step
# New Time Step: 0.0003125
# Error: Too many bisections
# ------------------------------------
# Simulation End
# ------------------------------------
# Total Time: 0:00:08.690255
# ------------------------------------
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
