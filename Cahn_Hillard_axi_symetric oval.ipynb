# %% [markdown]
# # Code for Cahn-Hilliard phase separation with mechanical coupling.

# %% [markdown]
# ## 2D phase separation study.

# %% [markdown]
# Degrees of freedom:
#   - scalar chemical potential: we use normalized  mu = mu/RT
#   - species concentration:  we use normalized  c= Omega*cmat
#
# ### Units:
# - Length: um
# - Mass: kg
# - Time: s
# - Amount of substance: pmol
# - Temperature: K
# - Mass density: kg/um^3
# - Force: uN
# - Stress: MPa
# - Energy: pJ
# - Species concentration: pmol/um^3
# - Chemical potential: pJ/pmol
# - Molar volume: um^3/pmol
# - Species diffusivity: um^2/s
# - Boltzmann Constant: 1.38E-11 pJ/K
# - Gas constant: 8.314  pJ/(pmol K)
#
# ### By
#   Eric Stewart      and      Lallit Anand
# ericstew@mit.edu            anand@mit.edu
#
# October 2023
#
# Modified for FenicsX by Jorge Nin
# jorgenin@mit.edu

# %%
import numpy as np


from mpi4py import MPI
from petsc4py import PETSc

from dolfinx import fem, mesh, io, plot, log, default_scalar_type
from dolfinx.fem import Constant, dirichletbc, Function, FunctionSpace, Expression
from dolfinx.fem.petsc import NonlinearProblem
from dolfinx.nls.petsc import NewtonSolver
from dolfinx.io import VTXWriter

import ufl
from ufl import (
    TestFunction,
    TrialFunction,
    Identity,
    grad,
    det,
    div,
    dev,
    inv,
    tr,
    sqrt,
    conditional,
    gt,
    dx,
    inner,
    derivative,
    dot,
    ln,
    split,
    tanh,
    as_tensor,
    as_vector,
    ge
)

from hilliard_models import Cahn_Hillard_axi_symmetric
from datetime import datetime
from dolfinx.plot import vtk_mesh

import pyvista

pyvista.set_jupyter_backend("client")
## Define temporal parameters
import random
import gmsh

# %% [markdown]
# # DEFINE GEOMETRY

# %%
problemName = "Canh Hillard Mechanical Axi Symetric Oval"
a = .5 #Semi major axis
b = .3 #Semi minor axis
lc = .01
points = [ [0,0],[0,a],[b,0]]
mesh_comm = MPI.COMM_WORLD
model_rank = 0


    
if mesh_comm.rank == model_rank:
    
    gmsh.initialize()
    gmsh.model.add("oval")
    meshpoints = []
    for point in points: 
        #print(point)
        meshpoints.append( gmsh.model.geo.add_point(point[0],point[1],0,lc))
    

    l3 = gmsh.model.geo.add_ellipse_arc(meshpoints[1],meshpoints[0], meshpoints[1], meshpoints[2])
    l1 = gmsh.model.geo.add_line(meshpoints[0], meshpoints[1])
    l2 = gmsh.model.geo.add_line(meshpoints[2], meshpoints[0])
    #l3 =gmsh.model.geo.add_line(meshpoints[2], meshpoints[0])
    
    loop = gmsh.model.geo.add_curve_loop([l1, l2, l3])
    
    surface = gmsh.model.geo.addPlaneSurface([1],1)
    
    
    gdim =2
    
    gmsh.model.geo.synchronize()
    
    gmsh.model.addPhysicalGroup(2, [surface],name="My Surface")
    
    BOTTOM_TAG, LEFT_TAG, OUTSIDE_TAG = 1, 2, 3
    gmsh.model.addPhysicalGroup(1,[l2],BOTTOM_TAG,"Bottom")
    gmsh.model.addPhysicalGroup(1,[l3],OUTSIDE_TAG,"Outside")
    gmsh.model.addPhysicalGroup(1,[l1],LEFT_TAG,"Left")
    
    
    gmsh.model.mesh.generate(2)
    

    
    gmsh.write("mesh/oval.msh")
    gmsh.finalize()
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Ellipse)
# Info    : [ 40%] Meshing curve 2 (Line)
# Info    : [ 70%] Meshing curve 3 (Line)
# Info    : Done meshing 1D (Wall 0.00124158s, CPU 0.001416s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0235965s, CPU 0.022668s)
# Info    : 1460 nodes 2921 elements
# Info    : Writing 'mesh/oval.msh'...
# Info    : Done writing 'mesh/oval.msh'

# %% [markdown]
# ## Read the Mesh and Visualize it

# %%
from dolfinx.io.gmshio import read_from_msh
domain, cell_tags, facet_tags = read_from_msh("mesh/oval.msh", MPI.COMM_WORLD, 0,gdim=2)
plotter = pyvista.Plotter()
vtkdata = vtk_mesh(domain, domain.topology.dim)
grid = pyvista.UnstructuredGrid(*vtkdata)
actor = plotter.add_mesh(grid, show_edges=True)



bottom_mesh = pyvista.UnstructuredGrid(*vtk_mesh(domain, domain.topology.dim-1,facet_tags.indices[facet_tags.values==BOTTOM_TAG]) )
left_mesh = pyvista.UnstructuredGrid(*vtk_mesh(domain, domain.topology.dim-1,facet_tags.indices[facet_tags.values==LEFT_TAG]) )
outside_mesh = pyvista.UnstructuredGrid(*vtk_mesh(domain, domain.topology.dim-1,facet_tags.indices[facet_tags.values==OUTSIDE_TAG]) )


actor = plotter.add_mesh(bottom_mesh, show_edges=True,color="blue")
actor2 = plotter.add_mesh(left_mesh, show_edges=True,color="red")
actor3 = plotter.add_mesh(outside_mesh, show_edges=True,color="green")

plotter.show()
plotter.view_xy()
plotter.close()
# Out:
# Info    : Reading 'mesh/oval.msh'...
# Info    : 7 entities
# Info    : 1460 nodes
# Info    : 2918 elements
# Info    : Done reading 'mesh/oval.msh'
# Widget(value="<iframe src='http://localhost:57974/index.html?ui=P_0x2a038be10_0&reconnect=auto' style='width: …

# %% [markdown]
# # Simulation Time Control

# %%
t = 0.0  # initialization of time
Ttot = 1800  # total simulation time
dt = 0.01  # Initial time step size, here we will use adaptive time-stepping

# %% [markdown]
# # Create Problem

# %%
dk = Constant(domain,dt)

cri = 0.005
crf = 0.995
def InitFunction(hillard_problem : Cahn_Hillard_axi_symmetric):

    # Some quick definitions to init random values
    V, _ = hillard_problem.ME.sub(1).collapse()
    cBar_init = Function(V)

    cBar_init.interpolate(
        lambda x: np.full_like(x[1],cri)
    ) 

    fc_rand =  (
        ln(cBar_init / (1 - cBar_init)) + hillard_problem.chi * (1 - 2 * cBar_init)
    )  # use that relation to initate the two different sub expressions

    concentration = Expression(
        hillard_problem.Omega*hillard_problem.cMax*cri,
        hillard_problem.ME.sub(2).element.interpolation_points(),
    )
    hillard_problem.w.sub(2).interpolate(concentration)

    chemical_potential = Expression(
        fc_rand , hillard_problem.ME.sub(1).element.interpolation_points()
    )
    hillard_problem.w.sub(1).interpolate(chemical_potential)

    hillard_problem.w.sub(0).interpolate(lambda x: np.zeros((2, x.shape[1])))

    hillard_problem.w_old.x.array[:] = hillard_problem.w.x.array
    hillard_problem.w_old_2.x.array[:] = hillard_problem.w.x.array

hillard_problem = Cahn_Hillard_axi_symmetric(domain,init_func=InitFunction)
hillard_problem.Kinematics()
hillard_problem.WeakForms(dk)

# %% [markdown]
# # Setup Output Files

# %%
U1 = ufl.VectorElement("Lagrange", domain.ufl_cell(), 1)
V2 = fem.FunctionSpace(domain, U1)#Vector function space
V1 = fem.FunctionSpace(domain, hillard_problem.P1)#Scalar function space

u_vis = Function(V2)
u_vis.name = "u"
u_expr = Expression(hillard_problem.u,V2.element.interpolation_points())


mu_vis = Function(V1)
mu_vis.name = "mu"
mu_expr = Expression(hillard_problem.mu,V1.element.interpolation_points())

c_vis = Function(V1)
c_vis.name = "c"
c_expr = Expression(hillard_problem.c,V1.element.interpolation_points())


T = hillard_problem.T #Cauchy Stress
T2D = as_tensor([[T[0,0], T[0,1]],
                                    [T[1,0], T[1,1]]])

sigma1, sigma2, vec1, vec2 = hillard_problem.eigs(T2D)

sigma1_vis = Function(V1)
sigma1_vis.name = "sigma1"
sigma1_expr = Expression(sigma1,V1.element.interpolation_points())

sigma2_vis = Function(V1)
sigma2_vis.name = "sigma2"
sigma2_expr = Expression(sigma2,V1.element.interpolation_points())


#vtk2 = VTXWriter(domain.comm,"results/"+problemName+"displacement.bp", [u_vis], engine="BP4" )

vtk = VTXWriter(domain.comm,"results/"+problemName+".bp", [u_vis,mu_vis,c_vis,sigma1_vis,sigma2_vis], engine="BP4" )

files = [vtk]

def interp_and_save(t, files: list[VTXWriter]):
    u_vis.interpolate(u_expr)
    mu_vis.interpolate(mu_expr)
    c_vis.interpolate(c_expr)
    sigma2_vis.interpolate(sigma2_expr)
    sigma1_vis.interpolate(sigma1_expr)

    for file in files:
        file.write(t)

# %% [markdown]
# # Boundary Conditions

# %%
# Just fix the sides to make sure they don't move

u_bc = np.array((0), dtype=default_scalar_type)




left_dofs = fem.locate_dofs_topological(hillard_problem.ME.sub(0).sub(0), facet_tags.dim, facet_tags.find(LEFT_TAG)) #we don't want it to move in the x direction
bottom_dofs = fem.locate_dofs_topological(hillard_problem.ME.sub(0).sub(1), facet_tags.dim, facet_tags.find(BOTTOM_TAG)) #we don't want it to move in the y direction
bcs = [fem.dirichletbc(u_bc, left_dofs, hillard_problem.ME.sub(0).sub(0)),
       fem.dirichletbc(u_bc, bottom_dofs, hillard_problem.ME.sub(0).sub(1))]

# %%
#Adding J external boundary condition
ds = ufl.Measure('ds', domain=domain, subdomain_data=facet_tags,metadata={'quadrature_degree': 4})


ui = np.log(cri/(1-cri)) + float(hillard_problem.chi)*(1-2*cri)
uf = np.log(crf/(1-crf)) + float(hillard_problem.chi)*(1-2*crf)


#slow ramp
def j_func(t):
    return (ui + (uf-ui)*t/Ttot)


mu_ext = Constant(domain,float(j_func(0.0)))

Jres =  dot(hillard_problem.Omega*(hillard_problem.mu-mu_ext),hillard_problem.mu_test)*hillard_problem.x[0]*ds(OUTSIDE_TAG)

hillard_problem.Res += Jres
hillard_problem.a = derivative(hillard_problem.Res, hillard_problem.w, hillard_problem.dw)

# %%
np.sum(hillard_problem.w.sub(1).collapse().x.array - j_func(0.0))
# Out:
# 0.0

# %%
dx = ufl.dx(metadata={"quadrature_degree": 4})

VolumetricCharge =fem.form(hillard_problem.cBar*hillard_problem.x[0]*dx)
Volume =fem.form(hillard_problem.x[0]*dx)

# %%
from dolfinx.fem.petsc import assemble_matrix, create_matrix, create_vector
import sys
from slepc4py import SLEPc

def CalcCond():
    jacobian = fem.form(hillard_problem.a)
    Residual = fem.form(hillard_problem.Res)
    A = create_matrix(jacobian)
    L = create_vector(Residual)

    assemble_matrix(A, jacobian, bcs=bcs)
    A.assemble()

    eigenSolver = SLEPc.EPS()
    eigenSolver.create(comm=mesh_comm)
    eigenSolver.which=SLEPc.EPS.Which.SMALLEST_REAL
    eigenSolver.setOperators(A)

    eigenSolver.solve()
    eigen_min = eigenSolver.getEigenvalue(0)

    eigenSolver.which=SLEPc.EPS.Which.LARGEST_REAL
    eigenSolver.solve()
    eigen_max = eigenSolver.getEigenvalue(0)
    
    
    return eigen_max/eigen_min

# %% [markdown]
# # Setup Nonlinear Problem

# %%
import os
step = "Swell"
jit_options ={"cffi_extra_compile_args":["-O3","-ffast-math"]}

problem = NonlinearProblem(hillard_problem.Res,hillard_problem.w, bcs, hillard_problem.a,jit_options=jit_options)


solver = NewtonSolver(MPI.COMM_WORLD, problem)
solver.convergence_criterion = "incremental"
solver.rtol = 1e-8
solver.atol = 1e-8
solver.max_it = 30
solver.report = True
solver.error_on_nonconvergence = False

ksp = solver.krylov_solver
opts = PETSc.Options()
option_prefix = ksp.getOptionsPrefix()
opts[f"{option_prefix}ksp_max_it"] = 30
#opts[f"{option_prefix}ksp_type"] = "preonly"
#opts[f"{option_prefix}pc_type"] = "lu"
opts[f"{option_prefix}pc_factor_mat_solver_type"] = "mumps"
ksp.setFromOptions()

startTime = datetime.now()
print("------------------------------------")
print("Simulation Start")
print("------------------------------------")

step = "Evolve"

#if os.path.exists("results/"+problemName+".bp"):
#    os.remove("results/"+problemName+".xdmf")
#    os.remove("results/"+problemName+".h5")

#vtk.write_mesh(domain)
t = 0.0
#log.set_log_level(log.LogLevel.INFO)
interp_and_save(t, files)
ii = 0
bisection_count = 0
times = []
volumes = []
charges = []
conditions = []
lasttimestep = hillard_problem.w_old_2.x.array.copy()
while t < Ttot:
    # increment time
    t += float(dk) 
    # increment counter
    ii +=1
    mu_ext.value = j_func(t)
    

    # Solve the problem
    
    (iter, converged) = solver.solve(hillard_problem.w)
    
    if converged:
        hillard_problem.w.x.scatter_forward()
        conditions.append(CalcCond())
        charges.append(fem.assemble_scalar(VolumetricCharge))
        volumes.append(fem.assemble_scalar(Volume))
        times.append(t)
        lasttimestep[:] = hillard_problem.w_old_2.x.array
        hillard_problem.w_old_2.x.array[:] = hillard_problem.w_old.x.array
        hillard_problem.w_old.x.array[:] = hillard_problem.w.x.array
        
        
        
        interp_and_save(t, files)
        if ii % 1 == 0:
            now = datetime.now()
            current_time = now.strftime("%H:%M:%S")
            print("Step: {} |   Increment: {} | Iterations: {}".format(step, ii, iter))
            print(f"Simulation Time: {t:.2f} s | dt: {dt:.4f}s | cond {conditions[-1]:.2f}")
            print()
        
        if iter <= 3:
            dt = 1.5 * dt
            dk.value = dt
        # If the newton solver takes 5 or more iterations,
        # decrease the time step by a factor of 2:
        elif iter >= 5:
            dt = dt / 2
            dk.value =dt
        
        #Reset Biseciton Counter
        bisection_count = 0
        
    else:
     # Break the loop if solver fails too many times
        bisection_count += 1
        
        if bisection_count > 10:
            print("Error: Too many bisections")
            break
        
        print( "Error Halfing Time Step")
        t = t - float(dk)
        dt = dt / 2
        dk.value = dt
        print(f"New Time Step: {dt}")    
        
        hillard_problem.w.x.array[:] = hillard_problem.w_old.x.array
        hillard_problem.w_old.x.array[:] = hillard_problem.w_old_2.x.array
        hillard_problem.w_old_2.x.array[:] = lasttimestep
        

#End Analysis

for file in files:
    file.close()
endTime = datetime.now()
print("------------------------------------")
print("Simulation End")
print("------------------------------------")
print("Total Time: {}".format(endTime - startTime))
print("------------------------------------")
# Out:
# ------------------------------------
# Simulation Start
# ------------------------------------
# Step: Evolve |   Increment: 1 | Iterations: 3
# Simulation Time: 0.01 s | dt: 0.0100s | cond -124.77-0.00j
#
# Step: Evolve |   Increment: 2 | Iterations: 2
# Simulation Time: 0.03 s | dt: 0.0150s | cond -124.77-0.00j
#
# Step: Evolve |   Increment: 3 | Iterations: 2
# Simulation Time: 0.05 s | dt: 0.0225s | cond -124.78-0.00j
#
# Step: Evolve |   Increment: 4 | Iterations: 2
# Simulation Time: 0.08 s | dt: 0.0338s | cond -124.78-0.00j
#
# Step: Evolve |   Increment: 5 | Iterations: 3
# Simulation Time: 0.13 s | dt: 0.0506s | cond -124.80-0.00j
#
# Step: Evolve |   Increment: 6 | Iterations: 3
# Simulation Time: 0.21 s | dt: 0.0759s | cond -124.82-0.00j
#
# Step: Evolve |   Increment: 7 | Iterations: 3
# Simulation Time: 0.32 s | dt: 0.1139s | cond -124.85-0.00j
#
# Step: Evolve |   Increment: 8 | Iterations: 3
# Simulation Time: 0.49 s | dt: 0.1709s | cond -124.90-0.00j
#
# Step: Evolve |   Increment: 9 | Iterations: 3
# Simulation Time: 0.75 s | dt: 0.2563s | cond -124.98-0.00j
#
# Step: Evolve |   Increment: 10 | Iterations: 3
# Simulation Time: 1.13 s | dt: 0.3844s | cond -125.10-0.00j
#
# Step: Evolve |   Increment: 11 | Iterations: 3
# Simulation Time: 1.71 s | dt: 0.5767s | cond -125.29-0.00j
#
# Step: Evolve |   Increment: 12 | Iterations: 3
# Simulation Time: 2.57 s | dt: 0.8650s | cond -125.57-0.00j
#
# Step: Evolve |   Increment: 13 | Iterations: 3
# Simulation Time: 3.87 s | dt: 1.2975s | cond -126.00-0.00j
#
# Step: Evolve |   Increment: 14 | Iterations: 3
# Simulation Time: 5.82 s | dt: 1.9462s | cond -126.66-0.00j
#
# Step: Evolve |   Increment: 15 | Iterations: 3
# Simulation Time: 8.74 s | dt: 2.9193s | cond -127.65-0.00j
#
# Step: Evolve |   Increment: 16 | Iterations: 4
# Simulation Time: 13.12 s | dt: 4.3789s | cond -129.16-0.00j
#
# Step: Evolve |   Increment: 17 | Iterations: 4
# Simulation Time: 17.50 s | dt: 4.3789s | cond -130.70-0.00j
#
# Step: Evolve |   Increment: 18 | Iterations: 4
# Simulation Time: 21.87 s | dt: 4.3789s | cond -132.25-0.00j
#
# Step: Evolve |   Increment: 19 | Iterations: 4
# Simulation Time: 26.25 s | dt: 4.3789s | cond -133.81-0.00j
#
# Step: Evolve |   Increment: 20 | Iterations: 4
# Simulation Time: 30.63 s | dt: 4.3789s | cond -135.40-0.00j
#
# Step: Evolve |   Increment: 21 | Iterations: 4
# Simulation Time: 35.01 s | dt: 4.3789s | cond -137.00-0.00j
#
# Step: Evolve |   Increment: 22 | Iterations: 4
# Simulation Time: 39.39 s | dt: 4.3789s | cond -138.63-0.00j
#
# Step: Evolve |   Increment: 23 | Iterations: 4
# Simulation Time: 43.77 s | dt: 4.3789s | cond -140.27-0.00j
#
# Step: Evolve |   Increment: 24 | Iterations: 4
# Simulation Time: 48.15 s | dt: 4.3789s | cond -141.94-0.00j
#
# Step: Evolve |   Increment: 25 | Iterations: 4
# Simulation Time: 52.53 s | dt: 4.3789s | cond -143.62-0.00j
#
# Step: Evolve |   Increment: 26 | Iterations: 4
# Simulation Time: 56.91 s | dt: 4.3789s | cond -145.33-0.00j
#
# Step: Evolve |   Increment: 27 | Iterations: 4
# Simulation Time: 61.29 s | dt: 4.3789s | cond -147.06-0.00j
#
# Step: Evolve |   Increment: 28 | Iterations: 4
# Simulation Time: 65.66 s | dt: 4.3789s | cond -148.81-0.00j
#
# Step: Evolve |   Increment: 29 | Iterations: 4
# Simulation Time: 70.04 s | dt: 4.3789s | cond -150.58-0.00j
#
# Step: Evolve |   Increment: 30 | Iterations: 4
# Simulation Time: 74.42 s | dt: 4.3789s | cond -152.37-0.00j
#
# Step: Evolve |   Increment: 31 | Iterations: 4
# Simulation Time: 78.80 s | dt: 4.3789s | cond -154.19-0.00j
#
# Step: Evolve |   Increment: 32 | Iterations: 4
# Simulation Time: 83.18 s | dt: 4.3789s | cond -156.03-0.00j
#
# Step: Evolve |   Increment: 33 | Iterations: 4
# Simulation Time: 87.56 s | dt: 4.3789s | cond -157.89-0.00j
#
# Step: Evolve |   Increment: 34 | Iterations: 4
# Simulation Time: 91.94 s | dt: 4.3789s | cond -159.77-0.00j
#
# Step: Evolve |   Increment: 35 | Iterations: 4
# Simulation Time: 96.32 s | dt: 4.3789s | cond -161.68-0.00j
#
# Step: Evolve |   Increment: 36 | Iterations: 4
# Simulation Time: 100.70 s | dt: 4.3789s | cond -163.61-0.00j
#
# Step: Evolve |   Increment: 37 | Iterations: 4
# Simulation Time: 105.07 s | dt: 4.3789s | cond -165.57-0.00j
#
# Step: Evolve |   Increment: 38 | Iterations: 4
# Simulation Time: 109.45 s | dt: 4.3789s | cond -167.55-0.00j
#
# Step: Evolve |   Increment: 39 | Iterations: 4
# Simulation Time: 113.83 s | dt: 4.3789s | cond -169.55-0.00j
#
# Step: Evolve |   Increment: 40 | Iterations: 4
# Simulation Time: 118.21 s | dt: 4.3789s | cond -171.58-0.00j
#
# Step: Evolve |   Increment: 41 | Iterations: 4
# Simulation Time: 122.59 s | dt: 4.3789s | cond -173.64-0.00j
#
# Step: Evolve |   Increment: 42 | Iterations: 4
# Simulation Time: 126.97 s | dt: 4.3789s | cond -175.72-0.00j
#
# Step: Evolve |   Increment: 43 | Iterations: 4
# Simulation Time: 131.35 s | dt: 4.3789s | cond -177.83-0.00j
#
# Step: Evolve |   Increment: 44 | Iterations: 4
# Simulation Time: 135.73 s | dt: 4.3789s | cond -179.96-0.00j
#
# Step: Evolve |   Increment: 45 | Iterations: 4
# Simulation Time: 140.11 s | dt: 4.3789s | cond -182.13-0.00j
#
# Step: Evolve |   Increment: 46 | Iterations: 4
# Simulation Time: 144.48 s | dt: 4.3789s | cond -184.32-0.00j
#
# Step: Evolve |   Increment: 47 | Iterations: 4
# Simulation Time: 148.86 s | dt: 4.3789s | cond -186.53-0.00j
#
# Step: Evolve |   Increment: 48 | Iterations: 4
# Simulation Time: 153.24 s | dt: 4.3789s | cond -188.78-0.00j
#
# Step: Evolve |   Increment: 49 | Iterations: 4
# Simulation Time: 157.62 s | dt: 4.3789s | cond -191.05-0.00j
#
# Step: Evolve |   Increment: 50 | Iterations: 4
# Simulation Time: 162.00 s | dt: 4.3789s | cond -193.35-0.00j
#
# Step: Evolve |   Increment: 51 | Iterations: 4
# Simulation Time: 166.38 s | dt: 4.3789s | cond -195.69-0.00j
#
# Step: Evolve |   Increment: 52 | Iterations: 4
# Simulation Time: 170.76 s | dt: 4.3789s | cond -198.05-0.00j
#
# Step: Evolve |   Increment: 53 | Iterations: 4
# Simulation Time: 175.14 s | dt: 4.3789s | cond -200.44-0.00j
#
# Step: Evolve |   Increment: 54 | Iterations: 4
# Simulation Time: 179.52 s | dt: 4.3789s | cond -202.86-0.00j
#
# Step: Evolve |   Increment: 55 | Iterations: 4
# Simulation Time: 183.90 s | dt: 4.3789s | cond -205.31-0.00j
#
# Step: Evolve |   Increment: 56 | Iterations: 4
# Simulation Time: 188.27 s | dt: 4.3789s | cond -207.80-0.00j
#
# Step: Evolve |   Increment: 57 | Iterations: 4
# Simulation Time: 192.65 s | dt: 4.3789s | cond -210.32-0.00j
#
# Step: Evolve |   Increment: 58 | Iterations: 4
# Simulation Time: 197.03 s | dt: 4.3789s | cond -212.87-0.00j
#
# Step: Evolve |   Increment: 59 | Iterations: 4
# Simulation Time: 201.41 s | dt: 4.3789s | cond -215.45-0.00j
#
# Step: Evolve |   Increment: 60 | Iterations: 4
# Simulation Time: 205.79 s | dt: 4.3789s | cond -218.06-0.00j
#
# Step: Evolve |   Increment: 61 | Iterations: 4
# Simulation Time: 210.17 s | dt: 4.3789s | cond -220.71-0.00j
#
# Step: Evolve |   Increment: 62 | Iterations: 4
# Simulation Time: 214.55 s | dt: 4.3789s | cond -223.39-0.00j
#
# Step: Evolve |   Increment: 63 | Iterations: 4
# Simulation Time: 218.93 s | dt: 4.3789s | cond -226.11-0.00j
#
# Step: Evolve |   Increment: 64 | Iterations: 4
# Simulation Time: 223.31 s | dt: 4.3789s | cond -228.87-0.00j
#
# Step: Evolve |   Increment: 65 | Iterations: 4
# Simulation Time: 227.68 s | dt: 4.3789s | cond -231.65-0.00j
#
# Step: Evolve |   Increment: 66 | Iterations: 4
# Simulation Time: 232.06 s | dt: 4.3789s | cond -234.48-0.00j
#
# Step: Evolve |   Increment: 67 | Iterations: 4
# Simulation Time: 236.44 s | dt: 4.3789s | cond -237.34-0.00j
#
# Step: Evolve |   Increment: 68 | Iterations: 4
# Simulation Time: 240.82 s | dt: 4.3789s | cond -240.24-0.00j
#
# Step: Evolve |   Increment: 69 | Iterations: 4
# Simulation Time: 245.20 s | dt: 4.3789s | cond -243.18-0.00j
#
# Step: Evolve |   Increment: 70 | Iterations: 4
# Simulation Time: 249.58 s | dt: 4.3789s | cond -246.15-0.00j
#
# Step: Evolve |   Increment: 71 | Iterations: 4
# Simulation Time: 253.96 s | dt: 4.3789s | cond -249.17-0.00j
#
# Step: Evolve |   Increment: 72 | Iterations: 4
# Simulation Time: 258.34 s | dt: 4.3789s | cond -252.22-0.00j
#
# Step: Evolve |   Increment: 73 | Iterations: 4
# Simulation Time: 262.72 s | dt: 4.3789s | cond -255.31-0.00j
#
# Step: Evolve |   Increment: 74 | Iterations: 4
# Simulation Time: 267.10 s | dt: 4.3789s | cond -258.45-0.00j
#
# Step: Evolve |   Increment: 75 | Iterations: 4
# Simulation Time: 271.47 s | dt: 4.3789s | cond -261.62-0.00j
#
# Step: Evolve |   Increment: 76 | Iterations: 4
# Simulation Time: 275.85 s | dt: 4.3789s | cond -264.84-0.00j
#
# Step: Evolve |   Increment: 77 | Iterations: 4
# Simulation Time: 280.23 s | dt: 4.3789s | cond -268.10-0.00j
#
# Step: Evolve |   Increment: 78 | Iterations: 4
# Simulation Time: 284.61 s | dt: 4.3789s | cond -271.40-0.00j
#
# Step: Evolve |   Increment: 79 | Iterations: 4
# Simulation Time: 288.99 s | dt: 4.3789s | cond -274.75-0.00j
#
# Step: Evolve |   Increment: 80 | Iterations: 4
# Simulation Time: 293.37 s | dt: 4.3789s | cond -278.14-0.00j
#
# Step: Evolve |   Increment: 81 | Iterations: 4
# Simulation Time: 297.75 s | dt: 4.3789s | cond -281.58-0.00j
#
# Step: Evolve |   Increment: 82 | Iterations: 4
# Simulation Time: 302.13 s | dt: 4.3789s | cond -285.06-0.00j
#
# Step: Evolve |   Increment: 83 | Iterations: 4
# Simulation Time: 306.51 s | dt: 4.3789s | cond -288.59-0.00j
#
# Step: Evolve |   Increment: 84 | Iterations: 4
# Simulation Time: 310.88 s | dt: 4.3789s | cond -292.16-0.00j
#
# Step: Evolve |   Increment: 85 | Iterations: 4
# Simulation Time: 315.26 s | dt: 4.3789s | cond -295.79-0.00j
#
# Step: Evolve |   Increment: 86 | Iterations: 4
# Simulation Time: 319.64 s | dt: 4.3789s | cond -299.46-0.00j
#
# Step: Evolve |   Increment: 87 | Iterations: 4
# Simulation Time: 324.02 s | dt: 4.3789s | cond -303.18-0.00j
#
# Step: Evolve |   Increment: 88 | Iterations: 4
# Simulation Time: 328.40 s | dt: 4.3789s | cond -306.95-0.00j
#
# Step: Evolve |   Increment: 89 | Iterations: 4
# Simulation Time: 332.78 s | dt: 4.3789s | cond -310.78-0.00j
#
# Step: Evolve |   Increment: 90 | Iterations: 4
# Simulation Time: 337.16 s | dt: 4.3789s | cond -314.65-0.00j
#
# Step: Evolve |   Increment: 91 | Iterations: 4
# Simulation Time: 341.54 s | dt: 4.3789s | cond -318.57-0.00j
#
# Step: Evolve |   Increment: 92 | Iterations: 4
# Simulation Time: 345.92 s | dt: 4.3789s | cond -322.55-0.00j
#
# Step: Evolve |   Increment: 93 | Iterations: 4
# Simulation Time: 350.30 s | dt: 4.3789s | cond -326.59-0.00j
#
# Step: Evolve |   Increment: 94 | Iterations: 4
# Simulation Time: 354.67 s | dt: 4.3789s | cond -330.67-0.00j
#
# Step: Evolve |   Increment: 95 | Iterations: 4
# Simulation Time: 359.05 s | dt: 4.3789s | cond -334.82-0.00j
#
# Step: Evolve |   Increment: 96 | Iterations: 4
# Simulation Time: 363.43 s | dt: 4.3789s | cond -339.02-0.00j
#
# Step: Evolve |   Increment: 97 | Iterations: 4
# Simulation Time: 367.81 s | dt: 4.3789s | cond -343.27-0.00j
#
# Step: Evolve |   Increment: 98 | Iterations: 4
# Simulation Time: 372.19 s | dt: 4.3789s | cond -347.59-0.00j
#
# Step: Evolve |   Increment: 99 | Iterations: 4
# Simulation Time: 376.57 s | dt: 4.3789s | cond -351.96-0.00j
#
# Step: Evolve |   Increment: 100 | Iterations: 4
# Simulation Time: 380.95 s | dt: 4.3789s | cond -356.40-0.00j
#
# Step: Evolve |   Increment: 101 | Iterations: 4
# Simulation Time: 385.33 s | dt: 4.3789s | cond -360.89-0.00j
#
# Step: Evolve |   Increment: 102 | Iterations: 4
# Simulation Time: 389.71 s | dt: 4.3789s | cond -365.45-0.00j
#
# Step: Evolve |   Increment: 103 | Iterations: 4
# Simulation Time: 394.08 s | dt: 4.3789s | cond -370.07-0.00j
#
# Step: Evolve |   Increment: 104 | Iterations: 4
# Simulation Time: 398.46 s | dt: 4.3789s | cond -374.75-0.00j
#
# Step: Evolve |   Increment: 105 | Iterations: 4
# Simulation Time: 402.84 s | dt: 4.3789s | cond -379.50-0.00j
#
# Step: Evolve |   Increment: 106 | Iterations: 4
# Simulation Time: 407.22 s | dt: 4.3789s | cond -384.32-0.00j
#
# Step: Evolve |   Increment: 107 | Iterations: 4
# Simulation Time: 411.60 s | dt: 4.3789s | cond -389.20-0.00j
#
# Step: Evolve |   Increment: 108 | Iterations: 4
# Simulation Time: 415.98 s | dt: 4.3789s | cond -394.15-0.00j
#
# Step: Evolve |   Increment: 109 | Iterations: 4
# Simulation Time: 420.36 s | dt: 4.3789s | cond -399.17-0.00j
#
# Step: Evolve |   Increment: 110 | Iterations: 4
# Simulation Time: 424.74 s | dt: 4.3789s | cond -404.25-0.00j
#
# Step: Evolve |   Increment: 111 | Iterations: 4
# Simulation Time: 429.12 s | dt: 4.3789s | cond -409.41-0.00j
#
# Step: Evolve |   Increment: 112 | Iterations: 4
# Simulation Time: 433.49 s | dt: 4.3789s | cond -414.65-0.00j
#
# Step: Evolve |   Increment: 113 | Iterations: 4
# Simulation Time: 437.87 s | dt: 4.3789s | cond -419.95-0.00j
#
# Step: Evolve |   Increment: 114 | Iterations: 4
# Simulation Time: 442.25 s | dt: 4.3789s | cond -425.33-0.00j
#
# Step: Evolve |   Increment: 115 | Iterations: 4
# Simulation Time: 446.63 s | dt: 4.3789s | cond -430.79-0.00j
#
# Step: Evolve |   Increment: 116 | Iterations: 4
# Simulation Time: 451.01 s | dt: 4.3789s | cond -436.32-0.00j
#
# Step: Evolve |   Increment: 117 | Iterations: 4
# Simulation Time: 455.39 s | dt: 4.3789s | cond -441.93-0.00j
#
# Step: Evolve |   Increment: 118 | Iterations: 4
# Simulation Time: 459.77 s | dt: 4.3789s | cond -447.62-0.00j
#
# Step: Evolve |   Increment: 119 | Iterations: 4
# Simulation Time: 464.15 s | dt: 4.3789s | cond -453.39-0.00j
#
# Step: Evolve |   Increment: 120 | Iterations: 4
# Simulation Time: 468.53 s | dt: 4.3789s | cond -459.24-0.00j
#
# Step: Evolve |   Increment: 121 | Iterations: 4
# Simulation Time: 472.91 s | dt: 4.3789s | cond -465.17-0.00j
#
# Step: Evolve |   Increment: 122 | Iterations: 4
# Simulation Time: 477.28 s | dt: 4.3789s | cond -471.19-0.00j
#
# Step: Evolve |   Increment: 123 | Iterations: 4
# Simulation Time: 481.66 s | dt: 4.3789s | cond -477.30-0.00j
#
# Step: Evolve |   Increment: 124 | Iterations: 4
# Simulation Time: 486.04 s | dt: 4.3789s | cond -483.49-0.00j
#
# Step: Evolve |   Increment: 125 | Iterations: 4
# Simulation Time: 490.42 s | dt: 4.3789s | cond -489.77-0.00j
#
# Step: Evolve |   Increment: 126 | Iterations: 4
# Simulation Time: 494.80 s | dt: 4.3789s | cond -496.14-0.00j
#
# Step: Evolve |   Increment: 127 | Iterations: 4
# Simulation Time: 499.18 s | dt: 4.3789s | cond -502.60-0.00j
#
# Step: Evolve |   Increment: 128 | Iterations: 4
# Simulation Time: 503.56 s | dt: 4.3789s | cond -509.16-0.00j
#
# Step: Evolve |   Increment: 129 | Iterations: 4
# Simulation Time: 507.94 s | dt: 4.3789s | cond -515.81-0.00j
#
# Step: Evolve |   Increment: 130 | Iterations: 4
# Simulation Time: 512.32 s | dt: 4.3789s | cond -522.55-0.00j
#
# Step: Evolve |   Increment: 131 | Iterations: 4
# Simulation Time: 516.69 s | dt: 4.3789s | cond -529.39-0.00j
#
# Step: Evolve |   Increment: 132 | Iterations: 4
# Simulation Time: 521.07 s | dt: 4.3789s | cond -536.33-0.00j
#
# Step: Evolve |   Increment: 133 | Iterations: 4
# Simulation Time: 525.45 s | dt: 4.3789s | cond -543.37-0.00j
#
# Step: Evolve |   Increment: 134 | Iterations: 4
# Simulation Time: 529.83 s | dt: 4.3789s | cond -550.52-0.00j
#
# Step: Evolve |   Increment: 135 | Iterations: 4
# Simulation Time: 534.21 s | dt: 4.3789s | cond -557.76-0.00j
#
# Step: Evolve |   Increment: 136 | Iterations: 4
# Simulation Time: 538.59 s | dt: 4.3789s | cond -565.11-0.00j
#
# Step: Evolve |   Increment: 137 | Iterations: 4
# Simulation Time: 542.97 s | dt: 4.3789s | cond -572.57-0.00j
#
# Step: Evolve |   Increment: 138 | Iterations: 4
# Simulation Time: 547.35 s | dt: 4.3789s | cond -580.13-0.00j
#
# Step: Evolve |   Increment: 139 | Iterations: 4
# Simulation Time: 551.73 s | dt: 4.3789s | cond -587.80-0.00j
#
# Step: Evolve |   Increment: 140 | Iterations: 4
# Simulation Time: 556.11 s | dt: 4.3789s | cond -595.58-0.00j
#
# Step: Evolve |   Increment: 141 | Iterations: 4
# Simulation Time: 560.48 s | dt: 4.3789s | cond -603.48-0.00j
#
# Step: Evolve |   Increment: 142 | Iterations: 4
# Simulation Time: 564.86 s | dt: 4.3789s | cond -611.49-0.00j
#
# Step: Evolve |   Increment: 143 | Iterations: 4
# Simulation Time: 569.24 s | dt: 4.3789s | cond -619.62-0.00j
#
# Step: Evolve |   Increment: 144 | Iterations: 4
# Simulation Time: 573.62 s | dt: 4.3789s | cond -627.86-0.00j
#
# Step: Evolve |   Increment: 145 | Iterations: 4
# Simulation Time: 578.00 s | dt: 4.3789s | cond -636.22-0.00j
#
# Step: Evolve |   Increment: 146 | Iterations: 4
# Simulation Time: 582.38 s | dt: 4.3789s | cond -644.71-0.00j
#
# Step: Evolve |   Increment: 147 | Iterations: 4
# Simulation Time: 586.76 s | dt: 4.3789s | cond -653.31-0.00j
#
# Step: Evolve |   Increment: 148 | Iterations: 4
# Simulation Time: 591.14 s | dt: 4.3789s | cond -662.04-0.00j
#
# Step: Evolve |   Increment: 149 | Iterations: 4
# Simulation Time: 595.52 s | dt: 4.3789s | cond -670.89-0.00j
#
# Step: Evolve |   Increment: 150 | Iterations: 4
# Simulation Time: 599.89 s | dt: 4.3789s | cond -679.87-0.00j
#
# Step: Evolve |   Increment: 151 | Iterations: 4
# Simulation Time: 604.27 s | dt: 4.3789s | cond -688.98-0.00j
#
# Step: Evolve |   Increment: 152 | Iterations: 4
# Simulation Time: 608.65 s | dt: 4.3789s | cond -698.22-0.00j
#
# Step: Evolve |   Increment: 153 | Iterations: 4
# Simulation Time: 613.03 s | dt: 4.3789s | cond -707.59-0.00j
#
# Step: Evolve |   Increment: 154 | Iterations: 4
# Simulation Time: 617.41 s | dt: 4.3789s | cond -717.09-0.00j
#
# Step: Evolve |   Increment: 155 | Iterations: 4
# Simulation Time: 621.79 s | dt: 4.3789s | cond -726.73-0.00j
#
# Step: Evolve |   Increment: 156 | Iterations: 4
# Simulation Time: 626.17 s | dt: 4.3789s | cond -736.50-0.00j
#
# Step: Evolve |   Increment: 157 | Iterations: 4
# Simulation Time: 630.55 s | dt: 4.3789s | cond -746.41-0.00j
#
# Step: Evolve |   Increment: 158 | Iterations: 4
# Simulation Time: 634.93 s | dt: 4.3789s | cond -756.46-0.00j
#
# Step: Evolve |   Increment: 159 | Iterations: 4
# Simulation Time: 639.31 s | dt: 4.3789s | cond -766.64-0.00j
#
# Step: Evolve |   Increment: 160 | Iterations: 4
# Simulation Time: 643.68 s | dt: 4.3789s | cond -776.96-0.00j
#
# Step: Evolve |   Increment: 161 | Iterations: 4
# Simulation Time: 648.06 s | dt: 4.3789s | cond -787.43-0.00j
#
# Step: Evolve |   Increment: 162 | Iterations: 4
# Simulation Time: 652.44 s | dt: 4.3789s | cond -798.03-0.00j
#
# Step: Evolve |   Increment: 163 | Iterations: 4
# Simulation Time: 656.82 s | dt: 4.3789s | cond -808.78-0.00j
#
# Step: Evolve |   Increment: 164 | Iterations: 4
# Simulation Time: 661.20 s | dt: 4.3789s | cond -819.67-0.00j
#
# Step: Evolve |   Increment: 165 | Iterations: 4
# Simulation Time: 665.58 s | dt: 4.3789s | cond -830.70-0.00j
#
# Step: Evolve |   Increment: 166 | Iterations: 4
# Simulation Time: 669.96 s | dt: 4.3789s | cond -841.87-0.00j
#
# Step: Evolve |   Increment: 167 | Iterations: 4
# Simulation Time: 674.34 s | dt: 4.3789s | cond -853.19-0.00j
#
# Step: Evolve |   Increment: 168 | Iterations: 4
# Simulation Time: 678.72 s | dt: 4.3789s | cond -864.65-0.00j
#
# Step: Evolve |   Increment: 169 | Iterations: 4
# Simulation Time: 683.09 s | dt: 4.3789s | cond -876.25-0.00j
#
# Step: Evolve |   Increment: 170 | Iterations: 4
# Simulation Time: 687.47 s | dt: 4.3789s | cond -887.99-0.00j
#
# Step: Evolve |   Increment: 171 | Iterations: 4
# Simulation Time: 691.85 s | dt: 4.3789s | cond -899.87-0.00j
#
# Step: Evolve |   Increment: 172 | Iterations: 4
# Simulation Time: 696.23 s | dt: 4.3789s | cond -911.89-0.00j
#
# Step: Evolve |   Increment: 173 | Iterations: 4
# Simulation Time: 700.61 s | dt: 4.3789s | cond -924.05-0.00j
#
# Step: Evolve |   Increment: 174 | Iterations: 4
# Simulation Time: 704.99 s | dt: 4.3789s | cond -936.34-0.00j
#
# Step: Evolve |   Increment: 175 | Iterations: 4
# Simulation Time: 709.37 s | dt: 4.3789s | cond -948.76-0.00j
#
# Step: Evolve |   Increment: 176 | Iterations: 4
# Simulation Time: 713.75 s | dt: 4.3789s | cond -961.31-0.00j
#
# Step: Evolve |   Increment: 177 | Iterations: 4
# Simulation Time: 718.13 s | dt: 4.3789s | cond -973.99-0.00j
#
# Step: Evolve |   Increment: 178 | Iterations: 4
# Simulation Time: 722.50 s | dt: 4.3789s | cond -986.79-0.00j
#
# Step: Evolve |   Increment: 179 | Iterations: 4
# Simulation Time: 726.88 s | dt: 4.3789s | cond -999.71-0.00j
#
# Step: Evolve |   Increment: 180 | Iterations: 4
# Simulation Time: 731.26 s | dt: 4.3789s | cond -1012.75-0.00j
#
# Step: Evolve |   Increment: 181 | Iterations: 4
# Simulation Time: 735.64 s | dt: 4.3789s | cond -1025.89-0.00j
#
# Step: Evolve |   Increment: 182 | Iterations: 4
# Simulation Time: 740.02 s | dt: 4.3789s | cond -1039.14-0.00j
#
# Step: Evolve |   Increment: 183 | Iterations: 4
# Simulation Time: 744.40 s | dt: 4.3789s | cond -1052.48-0.00j
#
# Step: Evolve |   Increment: 184 | Iterations: 4
# Simulation Time: 748.78 s | dt: 4.3789s | cond -1065.91-0.00j
#
# Step: Evolve |   Increment: 185 | Iterations: 4
# Simulation Time: 753.16 s | dt: 4.3789s | cond -1079.42-0.00j
#
# Step: Evolve |   Increment: 186 | Iterations: 4
# Simulation Time: 757.54 s | dt: 4.3789s | cond -1093.00-0.00j
#
# Step: Evolve |   Increment: 187 | Iterations: 4
# Simulation Time: 761.92 s | dt: 4.3789s | cond -1106.64-0.00j
#
# Step: Evolve |   Increment: 188 | Iterations: 4
# Simulation Time: 766.29 s | dt: 4.3789s | cond -1120.34-0.00j
#
# Step: Evolve |   Increment: 189 | Iterations: 4
# Simulation Time: 770.67 s | dt: 4.3789s | cond -1134.07-0.00j
#
# Step: Evolve |   Increment: 190 | Iterations: 4
# Simulation Time: 775.05 s | dt: 4.3789s | cond -1147.83-0.00j
#
# Step: Evolve |   Increment: 191 | Iterations: 4
# Simulation Time: 779.43 s | dt: 4.3789s | cond -1161.60-0.00j
#
# Step: Evolve |   Increment: 192 | Iterations: 4
# Simulation Time: 783.81 s | dt: 4.3789s | cond -1175.36-0.00j
#
# Step: Evolve |   Increment: 193 | Iterations: 4
# Simulation Time: 788.19 s | dt: 4.3789s | cond -1189.08-0.00j
#
# Step: Evolve |   Increment: 194 | Iterations: 4
# Simulation Time: 792.57 s | dt: 4.3789s | cond -1202.73-0.00j
#
# Step: Evolve |   Increment: 195 | Iterations: 4
# Simulation Time: 796.95 s | dt: 4.3789s | cond -1216.26-0.00j
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /Users/jorgenin/Documents/Python/Research/2.077/Cahn-Hilliard/Cahn_Hillard_axi_symetric oval.ipynb Cell 22 line 6
#      <a href='vscode-notebook-cell:/Users/jorgenin/Documents/Python/Research/2.077/Cahn-Hilliard/Cahn_Hillard_axi_symetric%20oval.ipynb#X26sZmlsZQ%3D%3D?line=58'>59</a> if converged:
#      <a href='vscode-notebook-cell:/Users/jorgenin/Documents/Python/Research/2.077/Cahn-Hilliard/Cahn_Hillard_axi_symetric%20oval.ipynb#X26sZmlsZQ%3D%3D?line=59'>60</a>     hillard_problem.w.x.scatter_forward()
# ---> <a href='vscode-notebook-cell:/Users/jorgenin/Documents/Python/Research/2.077/Cahn-Hilliard/Cahn_Hillard_axi_symetric%20oval.ipynb#X26sZmlsZQ%3D%3D?line=60'>61</a>     conditions.append(CalcCond())
#      <a href='vscode-notebook-cell:/Users/jorgenin/Documents/Python/Research/2.077/Cahn-Hilliard/Cahn_Hillard_axi_symetric%20oval.ipynb#X26sZmlsZQ%3D%3D?line=61'>62</a>     charges.append(fem.assemble_scalar(VolumetricCharge))
#      <a href='vscode-notebook-cell:/Users/jorgenin/Documents/Python/Research/2.077/Cahn-Hilliard/Cahn_Hillard_axi_symetric%20oval.ipynb#X26sZmlsZQ%3D%3D?line=62'>63</a>     volumes.append(fem.assemble_scalar(Volume))
#
# /Users/jorgenin/Documents/Python/Research/2.077/Cahn-Hilliard/Cahn_Hillard_axi_symetric oval.ipynb Cell 22 line 2
#      <a href='vscode-notebook-cell:/Users/jorgenin/Documents/Python/Research/2.077/Cahn-Hilliard/Cahn_Hillard_axi_symetric%20oval.ipynb#X26sZmlsZQ%3D%3D?line=16'>17</a> eigenSolver.setOperators(A)
#      <a href='vscode-notebook-cell:/Users/jorgenin/Documents/Python/Research/2.077/Cahn-Hilliard/Cahn_Hillard_axi_symetric%20oval.ipynb#X26sZmlsZQ%3D%3D?line=18'>19</a> eigenSolver.solve()
# ---> <a href='vscode-notebook-cell:/Users/jorgenin/Documents/Python/Research/2.077/Cahn-Hilliard/Cahn_Hillard_axi_symetric%20oval.ipynb#X26sZmlsZQ%3D%3D?line=19'>20</a> eigen_min = eigenSolver.getEigenvalue(0)
#      <a href='vscode-notebook-cell:/Users/jorgenin/Documents/Python/Research/2.077/Cahn-Hilliard/Cahn_Hillard_axi_symetric%20oval.ipynb#X26sZmlsZQ%3D%3D?line=21'>22</a> eigenSolver.which=SLEPc.EPS.Which.LARGEST_REAL
#      <a href='vscode-notebook-cell:/Users/jorgenin/Documents/Python/Research/2.077/Cahn-Hilliard/Cahn_Hillard_axi_symetric%20oval.ipynb#X26sZmlsZQ%3D%3D?line=22'>23</a> eigenSolver.solve()
#
# File slepc4py/SLEPc/EPS.pyx:1337, in slepc4py.SLEPc.EPS.getEigenvalue()
#
# Error: error code 63
# [0] EPSGetEigenvalue() at /Users/jorgenin/Documents/Python/Research/Libraries/slepc/src/eps/interface/epssolve.c:455
# [0] Argument out of range
# [0] The index can be nconv-1 at most, see EPSGetConverged()

# %%
C_res =fem.assemble_vector(fem.form(hillard_problem.Res_c))
mu_res = fem.assemble_vector(fem.form(hillard_problem.Res_mu))
u_res = fem.assemble_vector(fem.form(hillard_problem.Res_u))
FinalRes = fem.assemble_vector(fem.form(hillard_problem.Res))

mu_ext.value =  0
fem.set_bc(C_res.array,bcs)
fem.set_bc(mu_res.array,bcs)
fem.set_bc(u_res.array,bcs)
fem.set_bc(FinalRes.array,bcs)
#Print norms for different vectors
print(f"Final norm is {FinalRes.norm()}")
print(f"Norm for C {C_res.norm()}")
print(f"Norm for mu {mu_res.norm()}")
print(f"Norm for u {u_res.norm()}")
# Out:
# Final norm is 1.0724550480785078e-05
# Norm for C 2.9295987036499537e-06
# Norm for mu 0.0
# Norm for u 1.031665810475853e-05

# %%
mu_ext.value = j_func(t)
Jres2 = dot(hillard_problem.Omega*(hillard_problem.mu-mu_ext),hillard_problem.mu_test)*hillard_problem.x[0]*ds(OUTSIDE_TAG)

Boundary = fem.assemble_vector(fem.form( Jres2))
print(f"Boundary Value {Boundary.norm()}")
# Out:
# Boundary Value 2.549761315002592e-09

# %%
V, MEtoV = hillard_problem.ME.sub(1).collapse()
u = Function(V)
T = hillard_problem.Tr* hillard_problem.F.T/hillard_problem.J
TVal= Expression(T[0,0],V.element.interpolation_points())
u.interpolate(TVal)

# %%
plotter = pyvista.Plotter()
vtkdata = vtk_mesh(V1)
grid = pyvista.UnstructuredGrid(*vtkdata)

actor = plotter.add_mesh(grid, show_edges=True,scalars=u.x.array)

plotter.show()
plotter.view_xy()
plotter.close()
# Out:
# Widget(value="<iframe src='http://localhost:57479/index.html?ui=P_0x1070c8a90_0&reconnect=auto' style='width: …
#  JS Error => error: Uncaught TypeError: Cannot read properties of null (reading '0')

# %%
import matplotlib.pyplot as plt

font = {'size'   : 14}
plt.rc('font', **font)
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']


SOC = np.divide(charges,volumes)
fig = plt.figure()
ax = fig.gca()

plt.plot(times, SOC, linewidth=2.0,\
         color='g', marker='.')

plt.axis('tight')
plt.ylabel(r'State Of Charge')
plt.xlabel(r'Time (s)')

plt.grid(linestyle="--", linewidth=0.5, color='b')
from matplotlib.ticker import AutoMinorLocator,FormatStrFormatter
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())



fig.set_size_inches(7,5)
plt.tight_layout()
plt.savefig("results/"+problemName+".png", dpi=600)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/jorgenin/Documents/Python/Research/2.077/Cahn-Hilliard/Cahn_Hillard_axi_symetric oval.ipynb Cell 26 line 9
#       <a href='vscode-notebook-cell:/Users/jorgenin/Documents/Python/Research/2.077/Cahn-Hilliard/Cahn_Hillard_axi_symetric%20oval.ipynb#X34sZmlsZQ%3D%3D?line=4'>5</a> prop_cycle = plt.rcParams['axes.prop_cycle']
#       <a href='vscode-notebook-cell:/Users/jorgenin/Documents/Python/Research/2.077/Cahn-Hilliard/Cahn_Hillard_axi_symetric%20oval.ipynb#X34sZmlsZQ%3D%3D?line=5'>6</a> colors = prop_cycle.by_key()['color']
# ----> <a href='vscode-notebook-cell:/Users/jorgenin/Documents/Python/Research/2.077/Cahn-Hilliard/Cahn_Hillard_axi_symetric%20oval.ipynb#X34sZmlsZQ%3D%3D?line=8'>9</a> SOC = np.divide(charges,volumes)
#      <a href='vscode-notebook-cell:/Users/jorgenin/Documents/Python/Research/2.077/Cahn-Hilliard/Cahn_Hillard_axi_symetric%20oval.ipynb#X34sZmlsZQ%3D%3D?line=9'>10</a> fig = plt.figure()
#      <a href='vscode-notebook-cell:/Users/jorgenin/Documents/Python/Research/2.077/Cahn-Hilliard/Cahn_Hillard_axi_symetric%20oval.ipynb#X34sZmlsZQ%3D%3D?line=10'>11</a> ax = fig.gca()
#
# NameError: name 'charges' is not defined
